# %%
import pandas as pd

# %%
pd.read_csv("results/csv.csv")
# Out:
#       Q2  Q2_corr  Q2_corr_err    xbj  xbj_corr  xbj_corr_err      z  \
# 0    4.0  3.37275     0.010472  0.275  0.278487      0.000075  0.325
# 1    4.0  3.37644     0.007994  0.275  0.282134      0.000071  0.375
# 2    4.0  3.78996     0.016357  0.325  0.324579      0.000101  0.375
# 3    4.0  4.20543     0.016580  0.375  0.371190      0.000095  0.375
# 4    4.0  4.59366     0.011313  0.425  0.418406      0.000089  0.375
# ..   ...      ...          ...    ...       ...           ...    ...
# 382  5.5  4.50897     0.006706  0.475  0.479696      0.000082  0.475
# 383  5.5  4.89380     0.010140  0.525  0.522183      0.000101  0.475
# 384  5.5  4.49268     0.005573  0.475  0.481071      0.000073  0.525
# 385  5.5  4.76168     0.009330  0.525  0.513624      0.000054  0.525
# 386  5.5  4.43265     0.005502  0.475  0.471529      0.000061  0.575
#
#        z_corr  z_corr_err  RunGroup  ...  yield_neg_incnorad  \
# 0    0.344239    0.000007       100  ...            5.604380
# 1    0.373989    0.000102       100  ...           35.401900
# 2    0.376585    0.000093       100  ...           55.368600
# 3    0.380968    0.000080       100  ...           29.194300
# 4    0.386491    0.000042       100  ...            7.622660
# ..        ...         ...       ...  ...                 ...
# 382  0.491589    0.000015       430  ...            0.610819
# 383  0.492468    0.000013       430  ...            0.509033
# 384  0.522897    0.000096       430  ...            2.575700
# 385  0.515028    0.000055       430  ...            1.642740
# 386  0.560680    0.000035       430  ...            0.518265
#
#      yield_neg_incrad  yield_pos_incnorad  yield_pos_incrad  W2_corr  \
# 0            5.379800            8.151000          8.712500  9.62358
# 1           33.967200           52.288900         50.840300  9.47924
# 2           51.162800           83.349500         81.021600  8.77394
# 3           26.207400           44.622900         40.655700  8.01172
# 4            6.633420           11.791600         10.088500  7.27139
# ..                ...                 ...               ...      ...
# 382          0.504653            1.006970          0.861797  5.77451
# 383          0.399816            0.845958          0.734759  5.36111
# 384          2.185790            4.337090          3.815260  5.73079
# 385          1.316320            2.772340          2.168910  5.39132
# 386          0.458039            0.891454          0.776943  5.85161
#
#      Wp2_corr  xprime_corr  zprime_corr   shms_p  shms_dp
# 0     6.52152     0.273047     0.337436  2.22258 -8.46546
# 1     6.17179     0.276137     0.365692  2.38734 -1.68022
# 2     5.71100     0.316565     0.366879  2.34447 -3.44549
# 3     5.19479     0.360333     0.369801  2.30069 -5.24857
# 4     4.67926     0.404611     0.374031  2.26197 -6.84323
# ..        ...          ...          ...      ...      ...
# 382   3.17469     0.459530     0.471667  2.46426 -8.51451
# 383   2.95820     0.498534     0.470663  2.46102 -8.63456
# 384   2.99430     0.460560     0.501158  2.60498 -3.28996
# 385   2.87880     0.469592     0.469221  2.54618 -5.47297
# 386   2.86314     0.413755     0.517171  2.81215  4.40109
#
# [387 rows x 37 columns]

# %%
df = pd.read_csv("results/csv.csv")
df = df[df['shms_dp']>-9.5]
df = df[df['shms_dp']<24.5]
df.describe()
# Out:
#                Q2     Q2_corr  Q2_corr_err         xbj    xbj_corr  \
# count  387.000000  387.000000   387.000000  387.000000  387.000000
# mean     4.697674    4.374907     0.012825    0.448514    0.448760
# std      0.595216    0.708220     0.007137    0.074823    0.070167
# min      4.000000    3.072320     0.001459    0.275000    0.278487
# 25%      4.000000    3.846530     0.007259    0.375000    0.389602
# 50%      4.750000    4.424060     0.012191    0.425000    0.440770
# 75%      5.500000    4.886100     0.017653    0.525000    0.514415
# max      5.500000    6.060700     0.031787    0.625000    0.612865
#
#        xbj_corr_err           z      z_corr  z_corr_err    RunGroup  ...  \
# count    387.000000  387.000000  387.000000  387.000000  387.000000  ...
# mean       0.000082    0.462726    0.463463    0.000075  305.478036  ...
# std        0.000025    0.069774    0.066185    0.000031  142.060946  ...
# min        0.000014    0.325000    0.333986    0.000003   90.000000  ...
# 25%        0.000072    0.425000    0.423211    0.000050  180.000000  ...
# 50%        0.000094    0.475000    0.471058    0.000089  290.000000  ...
# 75%        0.000100    0.525000    0.518679    0.000100  440.000000  ...
# max        0.000111    0.675000    0.659579    0.000108  550.000000  ...
#
#        yield_neg_incnorad  yield_neg_incrad  yield_pos_incnorad  \
# count          387.000000        387.000000          387.000000
# mean            10.648208          9.479349           16.873481
# std             10.693538          9.660740           16.673942
# min              0.203569          0.181304            0.317505
# 25%              3.146945          2.698215            5.007215
# 50%              6.637630          5.900650           10.628600
# 75%             14.542900         12.845700           22.985300
# max             55.368600         52.285000           83.349500
#
#        yield_pos_incrad     W2_corr    Wp2_corr  xprime_corr  zprime_corr  \
# count        387.000000  387.000000  387.000000   387.000000   387.000000
# mean          15.267469    6.296240    3.637854     0.411178     0.427840
# std           15.310029    0.983591    0.685459     0.100608     0.104221
# min            0.286971    4.369330    2.842170    -0.000000    -0.000000
# 25%            4.341065    5.555060    3.068795     0.370928     0.402826
# 50%            9.706990    6.209230    3.472530     0.415228     0.447433
# 75%           20.880750    6.878250    4.042780     0.459748     0.493798
# max           81.021600    9.623580    6.521520     0.545935     0.640100
#
#            shms_p     shms_dp
# count  387.000000  387.000000
# mean     2.414620    2.610889
# std      0.387254    9.770223
# min      1.569590   -9.225080
# 25%      2.128520   -6.211820
# 50%      2.457350   -0.380967
# 75%      2.716350   10.869900
# max      3.402800   23.379000
#
# [8 rows x 37 columns]

# %%
df[df['Q2']==5.5][df['shms_dp']>-9.5][df['shms_dp']<24.5].head()
# Out:
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_27817/2809625863.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Q2']==5.5][df['shms_dp']>-9.5][df['shms_dp']<24.5].head()
#       Q2  Q2_corr  Q2_corr_err    xbj  xbj_corr  xbj_corr_err      z  \
# 278  5.5  4.54132     0.003848  0.375  0.388273      0.000032  0.325
# 279  5.5  4.92108     0.014692  0.425  0.423301      0.000102  0.325
# 280  5.5  5.45739     0.012135  0.475  0.470104      0.000088  0.325
# 281  5.5  4.54087     0.003446  0.375  0.388970      0.000031  0.375
# 282  5.5  4.88907     0.012361  0.425  0.426714      0.000099  0.375
#
#        z_corr  z_corr_err  RunGroup  ...  yield_neg_incnorad  \
# 278  0.343536    0.000007       480  ...            0.528045
# 279  0.344708    0.000007       480  ...            1.157370
# 280  0.344928    0.000006       480  ...            0.547474
# 281  0.374147    0.000099       480  ...            2.597770
# 282  0.374482    0.000099       480  ...           10.998500
#
#      yield_neg_incrad  yield_pos_incnorad  yield_pos_incrad  W2_corr  \
# 278          0.529877            0.798930          0.799017  8.03968
# 279          1.062920            1.767310          1.637460  7.58852
# 280          0.499378            0.842249          0.795942  7.03570
# 281          2.539680            3.994290          3.925410  8.01782
# 282         10.143800           17.032700         15.445200  7.45449
#
#      Wp2_corr  xprime_corr  zprime_corr   shms_p   shms_dp
# 278   5.46157     0.378276     0.333947  2.14158 -8.335370
# 279   5.15586     0.410065     0.333919  2.13577 -8.583780
# 280   4.78643     0.454296     0.333182  2.13418 -8.652160
# 281   5.22399     0.378157     0.363271  2.32895 -0.315239
# 282   4.87161     0.413097     0.362072  2.28783 -2.075480
#
# [5 rows x 37 columns]

# %%
xbj_ones_center = df[df['Q2']==4]['xbj'].unique()
for xi in xbj_ones_center:
    #for i,row in df[df['Q2']==4][df['xbj']==xi].iterrows():
    z_ones_center = df[df['Q2']==4][df['xbj']==xi]['z'].unique()
    #print(z_ones_center)
    for zi in z_ones_center:
        print(xi,zi)
        for i,row in df[df['Q2']==4][df['xbj']==xi][df['z']==zi].iterrows():
            #print(row['yield_neg_exc']/row['yield_neg_incrad'])
            #print(row['yield_neg_delta']/row['yield_neg_incrad'])
            #print(row['yield_neg']/row['yield_neg_incrad'])
            #print(row['yield_pos']/row['yield_pos_incrad'])
            #print(row['yield_pos_exc']/row['yield_pos_incrad'])
            print(row['yield_neg']/row['yield_pos'])
# Out:
# 0.275 0.325
# 0.768390669841448
# 0.275 0.375
# 0.655052940774643
# 0.275 0.425
# 0.7105989001109388
# 0.7499489146577121
# 0.275 0.475
# 0.630663344909155
# 0.7497165192930427
# 0.325 0.375
# 0.7094922479866793
# 0.6762264024970372
# 0.694057956234156
# 0.325 0.425
# 0.6803180843863726
# 0.7168211129221836
# 0.6862058013974168
# 0.6330642083570089
# 0.633375569718403
# 0.6507211872241996
# 0.635946079227332
# 0.325 0.475
# 0.7175619853012823
# 0.6521228526365148
# 0.6562178066658267
# 0.749344678033106
# 0.325 0.525
# 0.7801578992048446
# 0.668881941147905
# 0.6992662533416756
# 0.5747434738688926
# 0.5609050911376492
# 0.325 0.325
# 0.5947330884232906
# 0.325 0.575
# 0.658800677987514
# 0.7596197610468424
# 0.7310048036902116
# 0.45689933340154093
# 0.5320687180068377
# 0.325 0.675
# 0.7842837967730126
# 0.325 0.625
# 0.5929580876472872
# 0.375 0.375
# 0.7137140893834077
# 0.6466793611316208
# 0.6737713906139621
# 0.375 0.425
# 0.6721974626147181
# 0.6871707990149233
# 0.7396523519789105
# 0.7501476426204913
# 0.5901063347142607
# 0.6533897213012968
# 0.5985730534587943
# 0.375 0.475
# 0.6718607791705706
# 0.6664040131378774
# 0.6192687080580207
# 0.6731099575271354
# 0.6307974567424793
# 0.7023861814714284
# 0.7409103090941576
# 0.6471059103893921
# 0.7310724534513825
# 0.375 0.525
# 0.6741231320080725
# 0.7085695069626485
# 0.7840421703008309
# 0.6069954403938879
# 0.6284907060823484
# 0.7389856745072176
# 0.6591740445899362
# 0.375 0.575
# 0.6979892467681313
# 0.6686154370694238
# 0.6338095310653173
# 0.6924735514749132
# 0.6415386011616651
# 0.6759279089605604
# 0.6951160839850979
# 0.375 0.325
# 0.6769331416061043
# 0.7244669540920723
# 0.375 0.625
# 0.7427304782834782
# 0.6909476992143659
# 0.425 0.375
# 0.6011212584094381
# 0.6758243898217067
# 0.7024268888224678
# 0.425 0.425
# 0.6894778181542888
# 0.7260620834944023
# 0.6788277858176556
# 0.6216558562100067
# 0.7277031308292227
# 0.6849976601241905
# 0.425 0.475
# 0.6581130363081964
# 0.5831802244883222
# 0.6210707382179675
# 0.6485575621406028
# 0.606776928780991
# 0.548956588792366
# 0.6976987608056893
# 0.6547291184541333
# 0.425 0.525
# 0.7414357270287352
# 0.6711203897007655
# 0.6284454699023526
# 0.7499398433598712
# 0.5983968525853763
# 0.6440911095961823
# 0.6197954873143956
# 0.6070437489043756
# 0.425 0.575
# 0.7341018572304255
# 0.6648374997690446
# 0.6011046051953112
# 0.6927394797666655
# 0.5746687906394027
# 0.6042645155991154
# 0.425 0.325
# 0.6390428783916553
# 0.7251976107872242
# 0.475 0.425
# 0.630924081408904
# 0.7330877829138286
# 0.6823990467363962
# 0.6446347006277704
# 0.6976461895714587
# 0.475 0.475
# 0.7145494546428115
# 0.3965567602749512
# 0.6017016611454039
# 0.6655649923779511
# 0.587771405161819
# 0.6860272222887478
# 0.6587248691063502
# 0.5988707186172162
# 0.475 0.525
# 0.7454573885848319
# 0.6699660965941419
# 0.6386944990207797
# 0.5728575592693355
# 0.6754555735950911
# 0.6408863743517209
# 0.6735263077393697
# 0.475 0.575
# 0.6607331979517873
# 0.6643680851445207
# 0.6938026941345385
# 0.475 0.375
# 0.7331854980342701
# 0.6693796867152093
# 0.525 0.375
# 0.6572960340217278
# 0.7455730432290304
# 0.525 0.425
# 0.725537816896463
# 0.5449943860553296
# 0.525 0.475
# 0.7126745493822042
# 0.6816177959546801
# 0.7062300706733549
# 0.7457442606912231
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_27817/3321570961.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   z_ones_center = df[df['Q2']==4][df['xbj']==xi]['z'].unique()
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_27817/3321570961.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   for i,row in df[df['Q2']==4][df['xbj']==xi][df['z']==zi].iterrows():
