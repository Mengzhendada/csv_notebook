# %%
import pandas as pd

# %%
pd.read_csv("results/csv.csv")
# Out:
#       Q2  Q2_corr  Q2_corr_err  xbj_set    xbj  xbj_corr  xbj_corr_err  z_set  \
# 0    4.0  3.37174     0.010465     0.35  0.275  0.278381      0.000076    0.4
# 1    4.0  3.37682     0.007979     0.35  0.275  0.282171      0.000071    0.4
# 2    4.0  3.78948     0.016356     0.35  0.325  0.324535      0.000101    0.4
# 3    4.0  4.20512     0.016667     0.35  0.375  0.371180      0.000095    0.4
# 4    4.0  4.59370     0.011261     0.35  0.425  0.418401      0.000089    0.4
# ..   ...      ...          ...      ...    ...       ...           ...    ...
# 578  5.5  4.50897     0.006706     0.65  0.475  0.479696      0.000082    0.6
# 579  5.5  4.89380     0.010140     0.65  0.525  0.522183      0.000101    0.6
# 580  5.5  4.49268     0.005573     0.65  0.475  0.481071      0.000073    0.6
# 581  5.5  4.76168     0.009330     0.65  0.525  0.513624      0.000054    0.6
# 582  5.5  4.43265     0.005502     0.65  0.475  0.471529      0.000061    0.6
#
# ...

# %%
df = pd.read_csv("results/csv.csv")
df = df[df['shms_dp']>-9.5]
df = df[df['shms_dp']<24.5]
df.describe()
# Out:
#                Q2     Q2_corr  Q2_corr_err     xbj_set         xbj  \
# count  583.000000  583.000000   583.000000  583.000000  583.000000
# mean     4.666381    4.337849     0.012838    0.487650    0.429717
# std      0.596181    0.689388     0.007532    0.079853    0.077654
# min      4.000000    3.072320     0.001459    0.350000    0.275000
# 25%      4.000000    3.837095     0.007224    0.450000    0.375000
# 50%      4.750000    4.360920     0.011912    0.500000    0.425000
# 75%      5.500000    4.857555     0.017515    0.550000    0.475000
# max      5.500000    6.060700     0.042329    0.650000    0.625000
#
#          xbj_corr  xbj_corr_err       z_set           z      z_corr  ...  \
# count  583.000000    583.000000  583.000000  583.000000  583.000000  ...
# mean     0.430221      0.000082    0.519640    0.509220    0.508842  ...
# std      0.073017      0.000031    0.098508    0.093975    0.090435  ...
# ...

# %%
df[df['Q2']==5.5][df['shms_dp']>-9.5][df['shms_dp']<24.5].head()
# Out:
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_82465/2809625863.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Q2']==5.5][df['shms_dp']>-9.5][df['shms_dp']<24.5].head()
#       Q2  Q2_corr  Q2_corr_err  xbj_set    xbj  xbj_corr  xbj_corr_err  z_set  \
# 428  5.5  4.53068     0.008129      0.5  0.375  0.387176      0.000066    0.4
# 429  5.5  4.91601     0.028455      0.5  0.425  0.423052      0.000199    0.4
# 430  5.5  5.45307     0.022616      0.5  0.475  0.469707      0.000164    0.4
# 431  5.5  4.53902     0.007084      0.5  0.375  0.388721      0.000063    0.4
# 432  5.5  4.88592     0.024568      0.5  0.425  0.426242      0.000199    0.4
#
#          z    z_corr  ...  yield_neg_incnorad  yield_neg_incrad  \
# 428  0.325  0.343373  ...            0.763160          0.718461
# 429  0.325  0.344866  ...            1.447060          1.335310
# 430  0.325  0.344911  ...            0.705835          0.637095
# ...

# %%
xbj_ones_center = df[df['Q2']==4]['xbj'].unique()
for xi in xbj_ones_center:
    #for i,row in df[df['Q2']==4][df['xbj']==xi].iterrows():
    z_ones_center = df[df['Q2']==4][df['xbj']==xi]['z'].unique()
    #print(z_ones_center)
    for zi in z_ones_center:
        print(xi,zi)
        for i,row in df[df['Q2']==4][df['xbj']==xi][df['z']==zi].iterrows():
            #print(row['yield_neg_exc']/row['yield_neg_incrad'])
            #print(row['yield_neg_delta']/row['yield_neg_incrad'])
            #print(row['yield_neg']/row['yield_neg_incrad'])
            #print(row['yield_pos']/row['yield_pos_incrad'])
            #print(row['yield_pos_exc']/row['yield_pos_incrad'])
            print(row['yield_neg']/row['yield_pos'])
# Out:
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_82465/3321570961.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   z_ones_center = df[df['Q2']==4][df['xbj']==xi]['z'].unique()
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_82465/3321570961.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   for i,row in df[df['Q2']==4][df['xbj']==xi][df['z']==zi].iterrows():
# 0.275 0.325
# 0.7040099763878525
# 0.275 0.375
# 0.6166682169624913
# 0.275 0.425
# 0.666107699740238
# 0.744717747077929
# 0.275 0.475
# 0.5364289672369607
# 0.6682071797688294
# 0.7449085949154781
# 0.275 0.525
# 0.731995253377483
# 0.6397474243934862
# 0.6729243139829372
# 0.275 0.575
# 0.7731379712869335
# 0.6366572984571608
# 0.6571588338459192
# 0.6545966944593659
# 0.5363702209115836
# 0.275 0.625
# 0.6913876496830241
# 0.7030893854479392
# 0.7824110727159262
# 0.532281613959965
# 0.275 0.675
# 0.7009301187125199
# ...

# %%
print(df[df["Q2"]==4.75]["RunGroup"].unique())
# Out:
# [180 170 160 150 300 290 280 270 220 210 200 190 260 250 240 230]
