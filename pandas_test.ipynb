# %%
import pandas as pd
pd.read_csv('campass/HEPData-ins1444985-v1-Table_1.csv',header = 13)
# Out:
#       0.0087  0.004  0.01  0.443  0.3  0.5   1.149  0.223   0.2  0.25  1.8171  \
# 0     0.0088  0.004  0.01  0.435  0.3  0.5   1.138  0.274  0.25   0.3  1.2272
# 1     0.0088  0.004  0.01  0.435  0.3  0.5   1.138  0.324   0.3  0.35  0.9095
# 2     0.0088  0.004  0.01  0.435  0.3  0.5   1.138  0.374  0.35   0.4  0.6308
# 3     0.0088  0.004  0.01  0.435  0.3  0.5   1.138  0.424   0.4  0.45  0.4661
# 4     0.0088  0.004  0.01  0.432  0.3  0.5   1.132  0.474  0.45   0.5  0.3585
# ...      ...    ...   ...    ...  ...  ...     ...    ...   ...   ...     ...
# 1561    0.25   0.18   0.4  0.378  0.3  0.5  28.146  0.474  0.45   0.5  0.9623
# 1562    0.25   0.18   0.4  0.366  0.3  0.5  27.209  0.524   0.5  0.55  0.9631
# 1563  0.2501   0.18   0.4  0.353  0.3  0.5  26.174  0.574  0.55   0.6  0.9643
# 1564  0.2501   0.18   0.4   0.34  0.3  0.5  25.228  0.624   0.6  0.65  0.9656
# 1565  0.2502   0.18   0.4  0.329  0.3  0.5  24.339  0.674  0.65   0.7  0.9669
#
#       0.0155  -0.0155  0.0913  -0.0913
# 0     0.0125  -0.0125  0.0615  -0.0615
# 1     0.0112  -0.0112  0.0455  -0.0455
# 2     0.0095  -0.0095  0.0317  -0.0317
# 3     0.0084  -0.0084  0.0236  -0.0236
# 4     0.0079  -0.0079  0.0187  -0.0187
# ...      ...      ...     ...      ...
# 1561     NaN      NaN     NaN      NaN
# 1562     NaN      NaN     NaN      NaN
# 1563     NaN      NaN     NaN      NaN
# 1564     NaN      NaN     NaN      NaN
# 1565     NaN      NaN     NaN      NaN
#
# [1566 rows x 15 columns]

# %%
pd.read_csv("csv.csv")
# Out:
#       Q2  Q2_corr    xbj  xbj_corr      z    z_corr  RunGroup     y_RD  \
# 0    4.0  3.41265  0.275  0.287131  0.375  0.373679       100  4.90656
# 1    4.0  3.78067  0.325  0.325369  0.375  0.376778       100  6.03513
# 2    4.0  4.21136  0.375  0.370463  0.375  0.380219       100  6.32003
# 3    4.0  4.60732  0.425  0.416930  0.375  0.385171       100  3.08145
# 4    4.0  3.40722  0.275  0.286934  0.425  0.423533       100  5.52347
# ..   ...      ...    ...       ...    ...       ...       ...      ...
# 490  5.5  4.84762  0.525  0.524982  0.475  0.496001       430  1.25510
# 491  5.5  4.51577  0.475  0.490373  0.525  0.524295       430  3.48102
# 492  5.5  4.76434  0.525  0.524017  0.525  0.524465       430  3.02559
# 493  5.5  4.51856  0.475  0.490297  0.575  0.570247       430  2.55602
# 494  5.5  4.68969  0.525  0.512820  0.575  0.561371       430  2.69148
#
#      error_RD  y_RD_rho  yield_neg  yield_pos  charge_neg  charge_pos  \
# 0    1.024080   4.41151  11.733400  17.693000     91.8381     125.853
# 1    0.815065   5.60945  33.600200  47.928400     91.8381     125.853
# 2    1.085110   6.16331  22.480100  31.693200     91.8381     125.853
# 3    0.884974   2.93704   4.980740   8.641740     91.8381     125.853
# 4    1.124680   5.37014  10.270700  14.993900     91.8381     125.853
# ..        ...       ...        ...        ...         ...         ...
# 490  0.845860   1.21680   0.165701   0.386136    471.7990     266.696
# 491  1.463500   2.99969   0.433165   0.723165    471.7990     266.696
# 492  0.614971   2.73964   1.962250   3.424580    471.7990     266.696
# 493  1.283270   2.30778   0.319906   0.589791    471.7990     266.696
# 494  1.154720   2.44561   0.433696   0.786153    471.7990     266.696
#
#      yield_neg_rho  yield_pos_rho  yield_neg_incnorad  yield_neg_incrad  \
# 0         0.871904       0.871904           18.027700         16.920200
# 1         1.691030       1.691030           42.939200         39.463700
# 2         0.407240       0.407240           22.966200         20.580600
# 3         0.164195       0.164195            4.625790          4.080890
# 4         0.216260       0.216260           14.396300         14.290800
# ..             ...            ...                 ...               ...
# 490       0.002971       0.002971            0.098554          0.084458
# 491       0.033037       0.033037            0.517341          0.436813
# 492       0.130944       0.130944            2.419930          2.109520
# 493       0.013769       0.013769            0.400369          0.274698
# 494       0.022428       0.022428            0.492533          0.368322
#
#      yield_pos_incnorad  yield_pos_incrad
# 0             26.680200         25.882100
# 1             64.626400         62.366500
# 2             35.092500         32.245300
# 3              7.152000          6.064220
# 4             21.782900         22.783000
# ..                  ...               ...
# 490            0.163910          0.111938
# 491            0.872910          0.858889
# 492            4.112490          3.389010
# 493            0.696436          0.532290
# 494            0.855949          0.620185
#
# [495 rows x 20 columns]

# %%
df = pd.read_csv("csv.csv")

# %%
df.head()
# Out:
#     Q2  Q2_corr    xbj  xbj_corr      z    z_corr  RunGroup     y_RD  \
# 0  4.0  3.41265  0.275  0.287131  0.375  0.373679       100  4.90656
# 1  4.0  3.78067  0.325  0.325369  0.375  0.376778       100  6.03513
# 2  4.0  4.21136  0.375  0.370463  0.375  0.380219       100  6.32003
# 3  4.0  4.60732  0.425  0.416930  0.375  0.385171       100  3.08145
# 4  4.0  3.40722  0.275  0.286934  0.425  0.423533       100  5.52347
#
#    error_RD  y_RD_rho  yield_neg  yield_pos  charge_neg  charge_pos  \
# 0  1.024080   4.41151   11.73340   17.69300     91.8381     125.853
# 1  0.815065   5.60945   33.60020   47.92840     91.8381     125.853
# 2  1.085110   6.16331   22.48010   31.69320     91.8381     125.853
# 3  0.884974   2.93704    4.98074    8.64174     91.8381     125.853
# 4  1.124680   5.37014   10.27070   14.99390     91.8381     125.853
#
#    yield_neg_rho  yield_pos_rho  yield_neg_incnorad  yield_neg_incrad  \
# 0       0.871904       0.871904            18.02770          16.92020
# 1       1.691030       1.691030            42.93920          39.46370
# 2       0.407240       0.407240            22.96620          20.58060
# 3       0.164195       0.164195             4.62579           4.08089
# 4       0.216260       0.216260            14.39630          14.29080
#
#    yield_pos_incnorad  yield_pos_incrad
# 0             26.6802          25.88210
# 1             64.6264          62.36650
# 2             35.0925          32.24530
# 3              7.1520           6.06422
# 4             21.7829          22.78300

# %%
df.describe()
# Out:
#                Q2     Q2_corr         xbj    xbj_corr           z      z_corr  \
# count  495.000000  495.000000  495.000000  495.000000  495.000000  495.000000
# mean     4.672727    4.426851    0.445404    0.445912    0.520455    0.519728
# std      0.603393    0.670222    0.076406    0.072564    0.098442    0.094757
# min      4.000000    3.168560    0.275000    0.286343    0.325000    0.337211
# 25%      4.000000    3.883840    0.375000    0.389548    0.425000    0.438298
# 50%      4.750000    4.448900    0.425000    0.437899    0.525000    0.523460
# 75%      5.500000    4.889225    0.500000    0.500966    0.575000    0.578622
# max      5.500000    6.085990    0.625000    0.618416    0.775000    0.766682
#
#          RunGroup        y_RD    error_RD    y_RD_rho   yield_neg   yield_pos  \
# count  495.000000  495.000000  495.000000  495.000000  495.000000  495.000000
# mean   292.606061    4.410224    1.198260    3.960168    6.645816   10.441014
# std    149.114377    1.721014    0.797566    1.694088    6.412005   10.006046
# min     70.000000    0.419238    0.234374    0.165976    0.106934    0.275141
# 25%    160.000000    3.211790    0.677423    2.742550    1.902225    3.086065
# 50%    280.000000    4.183640    0.966511    3.764680    4.549030    7.180010
# 75%    435.000000    5.464765    1.453070    5.004085    9.078855   13.971700
# max    550.000000    9.969070    5.310130    9.182450   33.600200   51.855000
#
#         charge_neg  charge_pos  yield_neg_rho  yield_pos_rho  \
# count   495.000000  495.000000     495.000000     495.000000
# mean    279.219294  165.181041       0.478355       0.478355
# std     200.667557   99.616374       0.553208       0.553208
# min      46.648200   49.077000       0.000000       0.000000
# 25%     130.017000   90.797400       0.117058       0.117058
# 50%     242.611000  150.520000       0.269009       0.269009
# 75%     363.341000  210.156000       0.631355       0.631355
# max    1083.420000  497.192000       3.294160       3.294160
#
#        yield_neg_incnorad  yield_neg_incrad  yield_pos_incnorad  \
# count          495.000000        495.000000          495.000000
# mean             8.368235          7.236332           13.638276
# std              8.124365          7.165772           12.983106
# min              0.098554          0.084458            0.163910
# 25%              2.474725          2.074930            4.106475
# 50%              5.511220          4.698030            9.326340
# 75%             11.482900         10.004140           18.689750
# max             43.136600         41.519800           66.392700
#
#        yield_pos_incrad
# count        495.000000
# mean          11.950705
# std           11.566674
# min            0.111938
# 25%            3.559520
# 50%            7.964340
# 75%           16.568100
# max           63.484600

# %%
for row in df.itertuples():
    print(row.Q2_corr)
# Out:
# 3.41265
# 3.78067
# 4.21136
# 4.60732
# 3.40722
# 3.76969
# 4.18499
# 4.60551
# 3.41027
# 3.74423
# 4.15105
# 4.59732
# 3.83307
# 4.28794
# 3.4103
# 3.77429
# 4.19956
# 4.61048
# 3.41357
# 3.76928
# 4.19003
# 4.60421
# 3.41576
# 3.75525
# 4.16704
# 4.60175
# 4.09575
# 3.41077
# 3.8088
# 4.27746
# 3.41195
# 3.77438
# 4.20079
# 4.60582
# 3.4115
# 3.7667
# 4.18347
# 4.60119
# 3.41377
# 3.76146
# 4.17774
# 4.59544
# 3.72221
# 4.12415
# 4.54934
# 3.40733
# 3.80037
# 4.26384
# 3.40836
# 3.76922
# 4.19045
# 4.59622
# 3.4154
# 3.76763
# 4.1807
# 4.55497
# 3.40947
# 3.75008
# 3.45866
# 3.92113
# 4.32721
# 3.45282
# 3.81429
# 4.19351
# 4.5425
# 3.44959
# 3.80068
# 4.14329
# 4.51227
# 3.44908
# 3.75324
# 4.11447
# 4.50811
# 3.99557
# 3.45378
# 3.89525
# 4.30622
# 3.45125
# 3.80735
# 4.17984
# 4.53579
# 3.45103
# 3.79861
# 4.14454
# 4.49299
# 3.44449
# 3.77343
# 4.16059
# 3.64764
# 3.45688
# 3.8699
# 4.28831
# 3.45278
# 3.80737
# 4.20709
# 3.44418
# 3.79631
# 3.17938
# 3.48581
# 3.94357
# 3.43127
# 3.77587
# 4.11048
# 4.3998
# 3.16856
# 3.42552
# 3.71291
# 3.98718
# 4.2955
# 4.57322
# 3.36891
# 3.61043
# 3.90785
# 4.27041
# 3.76696
# 3.17377
# 3.46237
# 3.91209
# 4.25542
# 3.17454
# 3.42624
# 3.75169
# 4.09387
# 4.39261
# 3.17242
# 3.42259
# 3.72245
# 3.99153
# 4.34224
# 3.38213
# 3.646
# 3.99767
# 3.52673
# 3.17326
# 3.45248
# 3.87673
# 4.23514
# 3.16864
# 3.42446
# 3.75055
# 4.12147
# 3.17504
# 3.42433
# 3.76098
# 3.38608
# 3.49919
# 3.43644
# 3.86048
# 3.1739
# 3.40844
# 3.30402
# 3.65722
# 3.29812
# 3.56532
# 3.89095
# 4.19785
# 3.29792
# 3.54225
# 3.80497
# 4.04906
# 4.4054
# 3.46152
# 3.67785
# 3.30339
# 3.63074
# 4.04706
# 4.36221
# 3.29894
# 3.56124
# 3.86561
# 4.21619
# 3.29665
# 3.54649
# 3.83533
# 4.24487
# 3.46812
# 3.30002
# 3.60123
# 4.01441
# 4.34678
# 3.29882
# 3.56131
# 3.94878
# 3.29419
# 3.56467
# 3.68106
# 3.29437
# 3.5895
# 4.70516
# 4.16456
# 4.56642
# 4.94917
# 5.32084
# 4.1654
# 4.54305
# 4.90127
# 5.28649
# 4.16279
# 4.47642
# 4.83978
# 5.27476
# 4.16947
# 4.66746
# 5.07881
# 3.87118
# 4.16435
# 4.55576
# 4.93868
# 5.31084
# 3.87311
# 4.16547
# 4.54356
# 4.90262
# 5.28577
# 5.62912
# 4.16016
# 4.50371
# 4.87047
# 5.28121
# 4.42245
# 4.7487
# 4.16659
# 4.63932
# 5.07201
# 4.16646
# 4.54836
# 4.92736
# 5.3018
# 4.16078
# 4.54144
# 4.89607
# 4.15846
# 4.51902
# 4.94027
# 4.16753
# 4.61965
# 5.04336
# 4.16569
# 4.55186
# 4.96828
# 3.87321
# 4.14061
# 4.54368
# 4.47467
# 4.99081
# 4.15257
# 4.44632
# 4.83987
# 5.19791
# 5.53456
# 4.1551
# 4.44638
# 4.80409
# 5.13316
# 5.48553
# 4.4076
# 4.7117
# 5.04859
# 5.45303
# 4.15412
# 4.46588
# 4.96561
# 4.15203
# 4.4489
# 4.82551
# 5.18532
# 5.53344
# 4.15526
# 4.44945
# 4.80766
# 5.12563
# 5.47883
# 4.42995
# 4.74928
# 5.10216
# 4.15426
# 4.46814
# 4.93092
# 5.3295
# 4.15341
# 4.45131
# 4.81913
# 5.1995
# 4.15173
# 4.44985
# 4.82354
# 5.22361
# 4.15488
# 4.42951
# 4.83117
# 4.50568
# 4.15011
# 4.45954
# 4.90635
# 4.15177
# 4.4359
# 4.83245
# 4.41124
# 4.86372
# 4.01234
# 4.31239
# 4.66157
# 5.26849
# 4.01325
# 4.2986
# 4.59155
# 4.20679
# 4.46015
# 4.80605
# 4.01725
# 4.37747
# 4.81634
# 5.14503
# 4.01135
# 4.30493
# 4.63529
# 5.01343
# 4.01307
# 4.30339
# 4.632
# 3.99862
# 4.01724
# 4.35338
# 4.7867
# 4.01207
# 4.30722
# 4.7199
# 4.00189
# 4.30076
# 4.02114
# 4.44237
# 4.00128
# 4.30867
# 3.87114
# 3.86742
# 4.09954
# 4.38878
# 4.70952
# 3.86801
# 4.08849
# 4.35362
# 4.66488
# 4.11376
# 4.485
# 4.89072
# 3.8664
# 4.0986
# 4.38143
# 4.78944
# 3.86574
# 4.09256
# 4.38546
# 4.60038
# 3.86993
# 4.10475
# 4.0788
# 3.86612
# 4.08399
# 4.88854
# 4.57507
# 4.88375
# 5.29879
# 5.69015
# 4.57511
# 4.87593
# 5.28958
# 5.64689
# 4.88366
# 5.23613
# 5.60025
# 6.04794
# 4.88615
# 5.39954
# 4.88341
# 5.2893
# 5.68302
# 6.08599
# 4.88662
# 5.28728
# 5.65048
# 6.06223
# 4.88134
# 5.25988
# 5.64126
# 6.01708
# 5.18144
# 5.49255
# 4.5722
# 4.88761
# 5.36852
# 5.80368
# 4.57645
# 4.88991
# 5.29519
# 5.67831
# 6.05415
# 4.5745
# 4.88595
# 5.2911
# 5.65528
# 4.57712
# 4.88363
# 5.26997
# 4.57616
# 4.89298
# 5.35636
# 5.78612
# 4.5748
# 4.88527
# 5.28458
# 4.82425
# 4.98293
# 5.47902
# 4.64621
# 4.95376
# 5.33151
# 5.67459
# 6.02563
# 4.64133
# 4.95215
# 5.31148
# 5.61685
# 4.92892
# 5.24697
# 5.5889
# 4.64813
# 4.97238
# 5.43268
# 4.63859
# 4.94881
# 5.32723
# 5.6829
# 4.64152
# 4.95092
# 5.31511
# 5.67927
# 4.64293
# 4.93326
# 5.29824
# 4.64357
# 4.96949
# 5.4123
# 4.64766
# 4.94687
# 5.31205
# 4.63134
# 4.76134
# 5.13906
# 5.61634
# 4.75996
# 5.08457
# 5.43777
# 5.77408
# 4.75974
# 5.07445
# 5.41637
# 5.76654
# 5.01108
# 5.32997
# 4.75903
# 5.12567
# 5.56205
# 4.75658
# 5.07758
# 5.44124
# 4.76149
# 5.06704
# 4.74731
# 4.76227
# 5.0849
# 4.74687
# 4.77354
# 5.1945
# 4.76119
# 5.06882
# 5.42685
# 4.51858
# 4.75278
# 5.04335
# 4.92181
# 4.52139
# 4.77397
# 5.15861
# 5.55745
# 4.5123
# 4.76629
# 5.06659
# 4.52397
# 4.75295
# 5.05684
# 4.84762
# 4.51577
# 4.76434
# 4.51856
# 4.68969

# %%
pd.value_counts(df['Q2']).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['Q2_corr'].mean()
# Out:
# 4.426850565656565

# %%
df.groupby(['Q2']).mean()
# Out:
#        Q2_corr       xbj  xbj_corr         z    z_corr    RunGroup      y_RD  \
# Q2
# 4.00  3.821998  0.394149  0.393979  0.536436  0.535546  212.446809  4.506924
# 4.75  4.546267  0.460882  0.461456  0.509706  0.509235  226.352941  4.404682
# 5.50  5.108686  0.496533  0.497889  0.511861  0.511041  484.817518  4.284403
#
#       error_RD  y_RD_rho  yield_neg  yield_pos  charge_neg  charge_pos  \
# Q2
# 4.00  1.188207  3.989483  11.218681  17.645951  120.486789   79.224954
# 4.75  1.174996  3.959007   5.081990   7.958536  267.838929  172.995082
# 5.50  1.240925  3.921381   2.311157   3.634396  511.163620  273.439124
#
#       yield_neg_rho  yield_pos_rho  yield_neg_incnorad  yield_neg_incrad  \
# Q2
# 4.00       0.875213       0.875213           14.118680         12.240847
# 4.75       0.319604       0.319604            6.520306          5.630230
# 5.50       0.130752       0.130752            2.770162          2.361796
#
#       yield_pos_incnorad  yield_pos_incrad
# Q2
# 4.00           22.893091         20.098379
# 4.75           10.673345          9.353008
# 5.50            4.617349          3.993373

# %%
df[df['Q2']<4.85].groupby(['Q2','xbj']).mean() #sooooooooooo simple way to group!!!!!!!!!
# Out:
#              Q2_corr  xbj_corr         z    z_corr    RunGroup      y_RD  \
# Q2   xbj
# 4.00 0.275  3.411309  0.287382  0.575000  0.571831   83.571429  3.781287
#      0.325  3.524205  0.330219  0.561111  0.560440  188.333333  4.306079
#      0.375  3.720646  0.374604  0.546698  0.546079  213.584906  4.717108
#      0.425  4.009620  0.421116  0.536224  0.535325  233.061224  4.204880
#      0.475  4.093226  0.471237  0.498913  0.498241  262.173913  4.966500
#      0.525  4.283411  0.518264  0.456818  0.457108  248.181818  5.420357
#      0.575  4.489310  0.564420  0.425000  0.420164  245.000000  4.722775
# 4.75 0.325  3.872500  0.344940  0.575000  0.573615  163.333333  2.659379
#      0.375  4.158542  0.383720  0.545000  0.543289  217.600000  3.980774
#      0.425  4.304299  0.428541  0.519898  0.519447  223.673469  4.224476
#      0.475  4.616722  0.472222  0.515625  0.515008  225.416667  4.376308
#      0.525  4.915128  0.521098  0.478226  0.478798  233.548387  4.849279
#      0.575  5.164122  0.568224  0.451923  0.451537  254.615385  5.407108
#      0.625  5.268490  0.613576  0.375000  0.380903  220.000000  3.616260
#
#             error_RD  y_RD_rho  yield_neg  yield_pos  charge_neg  charge_pos  \
# Q2   xbj
# 4.00 0.275  0.955292  3.121391   6.824256  11.149561  111.695093   96.623036
#      0.325  1.071749  3.669453  13.055675  21.084079  112.738806   78.022414
#      0.375  1.179858  4.170906  13.295823  20.835330  115.112011   77.393864
#      0.425  1.108072  3.762875  10.420238  16.403475  121.453259   79.045863
#      0.475  1.378760  4.531257  10.605154  16.167543  133.179165   75.488670
#      0.525  1.737849  5.072205   7.069840  10.201069  146.808900   78.047000
#      0.575  1.884980  4.385465   3.305500   5.105055  149.511500   81.441750
# 4.75 0.325  1.473065  2.283233   0.498792   0.955093  236.499667  136.839000
#      0.375  1.028374  3.451174   4.675618   7.628977  265.385920  168.429400
#      0.425  1.131011  3.746166   5.502232   8.690864  259.832224  170.787286
#      0.475  1.108449  3.949402   5.750469   9.031488  263.463729  173.031896
#      0.525  1.201683  4.472566   5.121444   7.738895  284.088581  178.956097
#      0.575  1.716969  4.985573   3.052844   4.436172  288.207308  181.231462
#      0.625  1.422930  3.306740   1.467810   2.421710  256.992000  210.156000
#
#             yield_neg_rho  yield_pos_rho  yield_neg_incnorad  \
# Q2   xbj
# 4.00 0.275       0.807637       0.807637            9.476715
#      0.325       1.285968       1.285968           17.635066
#      0.375       1.083018       1.083018           16.920695
#      0.425       0.660799       0.660799           12.839852
#      0.475       0.593289       0.593289           12.071183
#      0.525       0.291125       0.291125            6.994697
#      0.575       0.155611       0.155611            3.123545
# 4.75 0.325       0.048236       0.048236            1.040339
#      0.375       0.354042       0.354042            6.197656
#      0.425       0.387388       0.387388            7.498200
#      0.475       0.339418       0.339418            7.286890
#      0.525       0.258654       0.258654            6.055547
#      0.575       0.150947       0.150947            3.388050
#      0.625       0.082359       0.082359            1.440460
#
#             yield_neg_incrad  yield_pos_incnorad  yield_pos_incrad
# Q2   xbj
# 4.00 0.275          8.523849           14.986254         13.637105
#      0.325         15.536001           28.538189         25.515627
#      0.375         14.603540           27.608660         24.181431
#      0.425         11.031135           20.945196         18.197045
#      0.475         10.337350           19.428878         16.720629
#      0.525          5.915789           10.970301          9.372716
#      0.575          2.651705            4.803800          4.033955
# 4.75 0.325          0.963489            1.692393          1.488549
#      0.375          5.474107           10.157748          9.019076
#      0.425          6.517252           12.359364         10.931010
#      0.475          6.268589           11.969558         10.472189
#      0.525          5.132400            9.788023          8.405655
#      0.575          2.836828            5.362634          4.575324
#      0.625          1.175210            2.157160          1.729740

# %%
import json
with open('yield_ratio_Q2xzRunG_combined.json') as j_RD:
    RDxz = json.load(j_RD)
for key_Q2,Q2_value in RDxz.items():
    Q2 = float(key_Q2)
    #print(Q2)
    for key_xbj,xbj_value in Q2_value.items():
        xbj = float(key_xbj) 
        for key_z,z_value in xbj_value.items():
            z_hadron = float(key_z)
            for key_RunG,RunG_value in z_value.items():
                RunGroup = float(key_RunG)
                RD=float(RunG_value["value"])
                RD_error = float(RunG_value["error"])
                xbj_corr = float(RunG_value["xbj_corr"])
                z_corr = float(RunG_value["z_corr"])
                csv_value = df[df['Q2']==Q2][df['xbj']==xbj][df['z']==z_hadron][df['RunGroup']==RunGroup]['y_RD']
                print('from csv file ',csv_value)
                print('from json file ',RD)
    #plt.savefig("RD_xbj_z_"+str(Q2)+".png")
# Out:
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_33996/2193712879.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   csv_value = df[df['Q2']==Q2][df['xbj']==xbj][df['z']==z_hadron][df['RunGroup']==RunGroup]['y_RD']
# from csv file  0    4.90656
# Name: y_RD, dtype: float64
# from json file  4.906559258931412
# from csv file  4    5.52347
# Name: y_RD, dtype: float64
# from json file  5.523468346686559
# from csv file  8    1.90836
# Name: y_RD, dtype: float64
# from json file  1.9083597202996738
# from csv file  14    6.89565
# Name: y_RD, dtype: float64
# from json file  6.895646387485501
# from csv file  27    2.2161
# Name: y_RD, dtype: float64
# from json file  2.2160997551063173
# from csv file  18    8.56395
# Name: y_RD, dtype: float64
# from json file  8.56395140021219
# from csv file  30    2.9301
# Name: y_RD, dtype: float64
# from json file  2.9301001856440316
# from csv file  22    3.61453
# Name: y_RD, dtype: float64
# from json file  3.614534644414758
# from csv file  45    3.80491
# Name: y_RD, dtype: float64
# from json file  3.8049141374663287
# from csv file  34    3.612
# Name: y_RD, dtype: float64
# from json file  3.6120003925238016
# from csv file  48    1.75496
# Name: y_RD, dtype: float64
# from json file  1.7549575411247416
# from csv file  38    3.24383
# Name: y_RD, dtype: float64
# from json file  3.243831173643643
# from csv file  52    2.07699
# Name: y_RD, dtype: float64
# from json file  2.076988366439425
# from csv file  56    1.88661
# Name: y_RD, dtype: float64
# from json file  1.8866089326007174
# from csv file  97    5.21953
# Name: y_RD, dtype: float64
# from json file  5.219530847274809
# from csv file  1    6.03513
# Name: y_RD, dtype: float64
# from json file  6.035128398575636
# from csv file  5    4.44469
# Name: y_RD, dtype: float64
# from json file  4.444691036461572
# from csv file  115    3.28376
# Name: y_RD, dtype: float64
# from json file  3.283761471168882
# from csv file  104    4.54045
# Name: y_RD, dtype: float64
# from json file  4.5404542865044
# from csv file  58    5.65159
# Name: y_RD, dtype: float64
# from json file  5.651593503175812
# from csv file  12    6.39718
# Name: y_RD, dtype: float64
# from json file  6.39717818370155
# from csv file  9    5.5633
# Name: y_RD, dtype: float64
# from json file  5.563302430914814
# from csv file  119    3.99285
# Name: y_RD, dtype: float64
# from json file  3.9928475959242427
# from csv file  61    4.82629
# Name: y_RD, dtype: float64
# from json file  4.826294208450452
# from csv file  15    5.35256
# Name: y_RD, dtype: float64
# from json file  5.35256041804102
# from csv file  133    3.84656
# Name: y_RD, dtype: float64
# from json file  3.8465566667890796
# from csv file  124    6.32947
# Name: y_RD, dtype: float64
# from json file  6.329474195046301
# from csv file  74    5.42132
# Name: y_RD, dtype: float64
# from json file  5.421324527030078
# from csv file  65    4.47749
# Name: y_RD, dtype: float64
# from json file  4.477493912059296
# from csv file  28    4.57173
# Name: y_RD, dtype: float64
# from json file  4.5717335104664585
# from csv file  19    4.23742
# Name: y_RD, dtype: float64
# from json file  4.237417521908901
# from csv file  137    8.42985
# Name: y_RD, dtype: float64
# from json file  8.429850949845505
# from csv file  77    3.94807
# Name: y_RD, dtype: float64
# from json file  3.9480683434850197
# from csv file  69    3.89061
# Name: y_RD, dtype: float64
# from json file  3.8906080200837465
# from csv file  31    3.97831
# Name: y_RD, dtype: float64
# from json file  3.97831472563249
# from csv file  23    3.63265
# Name: y_RD, dtype: float64
# from json file  3.6326483348002085
# from csv file  141    4.01551
# Name: y_RD, dtype: float64
# from json file  4.015508815233055
# from csv file  89    2.48022
# Name: y_RD, dtype: float64
# from json file  2.480224806279348
# from csv file  81    4.79302
# Name: y_RD, dtype: float64
# from json file  4.793015113681516
# from csv file  46    2.05949
# Name: y_RD, dtype: float64
# from json file  2.059494607098738
# from csv file  35    3.83479
# Name: y_RD, dtype: float64
# from json file  3.834788970609868
# from csv file  148    6.98042
# Name: y_RD, dtype: float64
# from json file  6.980415319261111
# from csv file  92    2.9734
# Name: y_RD, dtype: float64
# from json file  2.973396490311365
# from csv file  85    2.91245
# Name: y_RD, dtype: float64
# from json file  2.912447272715871
# from csv file  49    2.33275
# Name: y_RD, dtype: float64
# from json file  2.332749803326853
# from csv file  39    2.07445
# Name: y_RD, dtype: float64
# from json file  2.074445240655772
# from csv file  95    4.00224
# Name: y_RD, dtype: float64
# from json file  4.002242658877633
# from csv file  53    1.96749
# Name: y_RD, dtype: float64
# from json file  1.9674859495663517
# from csv file  42    4.50869
# Name: y_RD, dtype: float64
# from json file  4.508687546058822
# from csv file  57    2.01311
# Name: y_RD, dtype: float64
# from json file  2.0131127010989722
# from csv file  98    4.53525
# Name: y_RD, dtype: float64
# from json file  4.5352494872946565
# from csv file  150    6.36628
# Name: y_RD, dtype: float64
# from json file  6.366277487177457
# from csv file  2    6.32003
# Name: y_RD, dtype: float64
# from json file  6.320029655917119
# from csv file  100    4.59505
# Name: y_RD, dtype: float64
# from json file  4.595047539463521
# from csv file  152    5.45983
# Name: y_RD, dtype: float64
# from json file  5.459831371807038
# from csv file  6    4.08286
# Name: y_RD, dtype: float64
# from json file  4.082861875111867
# from csv file  116    3.55465
# Name: y_RD, dtype: float64
# from json file  3.5546465522224966
# from csv file  105    7.90983
# Name: y_RD, dtype: float64
# from json file  7.909826382461032
# from csv file  163    4.80815
# Name: y_RD, dtype: float64
# from json file  4.8081470663569
# from csv file  156    6.62521
# Name: y_RD, dtype: float64
# from json file  6.625211443113203
# from csv file  59    9.25594
# Name: y_RD, dtype: float64
# from json file  9.255935264181655
# from csv file  13    3.70256
# Name: y_RD, dtype: float64
# from json file  3.7025561612163007
# from csv file  10    5.1046
# Name: y_RD, dtype: float64
# from json file  5.1046039321919325
# from csv file  120    4.69477
# Name: y_RD, dtype: float64
# from json file  4.694765640955824
# from csv file  110    3.70811
# Name: y_RD, dtype: float64
# from json file  3.7081061549088092
# from csv file  167    3.30191
# Name: y_RD, dtype: float64
# from json file  3.301913975424051
# from csv file  62    4.42664
# Name: y_RD, dtype: float64
# from json file  4.426639168753371
# from csv file  16    4.14461
# Name: y_RD, dtype: float64
# from json file  4.144613667341005
# from csv file  134    6.04889
# Name: y_RD, dtype: float64
# from json file  6.048889901947266
# from csv file  125    3.3786
# Name: y_RD, dtype: float64
# from json file  3.3785954276625474
# from csv file  176    5.60029
# Name: y_RD, dtype: float64
# from json file  5.600285608477952
# from csv file  171    7.20085
# Name: y_RD, dtype: float64
# from json file  7.200847656398182
# from csv file  75    6.54285
# Name: y_RD, dtype: float64
# from json file  6.542846511955334
# from csv file  66    5.16396
# Name: y_RD, dtype: float64
# from json file  5.163956577374933
# from csv file  29    3.33732
# Name: y_RD, dtype: float64
# from json file  3.3373239149458893
# from csv file  20    6.00526
# Name: y_RD, dtype: float64
# from json file  6.005257680413739
# from csv file  145    5.58928
# Name: y_RD, dtype: float64
# from json file  5.589281532422636
# from csv file  138    4.15454
# Name: y_RD, dtype: float64
# from json file  4.15453906383884
# from csv file  129    9.96907
# Name: y_RD, dtype: float64
# from json file  9.969065031001092
# from csv file  180    5.32401
# Name: y_RD, dtype: float64
# from json file  5.324008995018361
# from csv file  78    3.96897
# Name: y_RD, dtype: float64
# from json file  3.968971849908308
# from csv file  70    5.73304
# Name: y_RD, dtype: float64
# from json file  5.733040808252208
# from csv file  32    3.57701
# Name: y_RD, dtype: float64
# from json file  3.577007426063343
# from csv file  24    3.87754
# Name: y_RD, dtype: float64
# from json file  3.877544863877777
# from csv file  146    4.42486
# Name: y_RD, dtype: float64
# from json file  4.4248631437741075
# from csv file  142    3.91787
# Name: y_RD, dtype: float64
# from json file  3.917865166799015
# from csv file  186    5.14486
# Name: y_RD, dtype: float64
# from json file  5.144855162848765
# from csv file  183    6.65355
# Name: y_RD, dtype: float64
# from json file  6.65354853141455
# from csv file  90    4.25983
# Name: y_RD, dtype: float64
# from json file  4.259832977434352
# from csv file  82    2.72186
# Name: y_RD, dtype: float64
# from json file  2.721856323198626
# from csv file  47    2.03277
# Name: y_RD, dtype: float64
# from json file  2.0327721535934073
# from csv file  36    2.48518
# Name: y_RD, dtype: float64
# from json file  2.4851828082372323
# from csv file  26    2.69236
# Name: y_RD, dtype: float64
# from json file  2.692361700050822
# from csv file  149    8.87559
# Name: y_RD, dtype: float64
# from json file  8.875591435362574
# from csv file  144    6.99464
# Name: y_RD, dtype: float64
# from json file  6.994640731318194
# from csv file  93    3.2478
# Name: y_RD, dtype: float64
# from json file  3.247801006609077
# from csv file  86    3.21737
# Name: y_RD, dtype: float64
# from json file  3.2173669703104175
# from csv file  50    2.52212
# Name: y_RD, dtype: float64
# from json file  2.5221167238667546
# from csv file  40    2.3336
# Name: y_RD, dtype: float64
# from json file  2.3335962302065787
# from csv file  96    2.95793
# Name: y_RD, dtype: float64
# from json file  2.9579255487077347
# from csv file  88    0.904971
# Name: y_RD, dtype: float64
# from json file  0.9049707575488555
# from csv file  54    2.92721
# Name: y_RD, dtype: float64
# from json file  2.9272059852745227
# from csv file  43    3.62458
# Name: y_RD, dtype: float64
# from json file  3.624576767628435
# from csv file  99    7.83612
# Name: y_RD, dtype: float64
# from json file  7.836123164346971
# from csv file  151    5.88915
# Name: y_RD, dtype: float64
# from json file  5.889147060475513
# from csv file  3    3.08145
# Name: y_RD, dtype: float64
# from json file  3.081454961190699
# from csv file  101    4.97223
# Name: y_RD, dtype: float64
# from json file  4.972234521069706
# from csv file  153    6.49872
# Name: y_RD, dtype: float64
# from json file  6.498721861749161
# from csv file  7    5.88328
# Name: y_RD, dtype: float64
# from json file  5.883282388771611
# from csv file  117    3.32121
# Name: y_RD, dtype: float64
# from json file  3.321213787831202
# from csv file  106    5.47479
# Name: y_RD, dtype: float64
# from json file  5.4747909987698495
# from csv file  164    5.74059
# Name: y_RD, dtype: float64
# from json file  5.7405914881261015
# from csv file  157    6.42173
# Name: y_RD, dtype: float64
# from json file  6.4217250435207145
# from csv file  60    5.31326
# Name: y_RD, dtype: float64
# from json file  5.3132608355614
# from csv file  11    4.07646
# Name: y_RD, dtype: float64
# from json file  4.076458692107668
# from csv file  121    3.61313
# Name: y_RD, dtype: float64
# from json file  3.6131266671496123
# from csv file  111    5.46994
# Name: y_RD, dtype: float64
# from json file  5.4699388406584335
# from csv file  168    5.0614
# Name: y_RD, dtype: float64
# from json file  5.061401891287798
# from csv file  161    5.60553
# Name: y_RD, dtype: float64
# from json file  5.6055303324589945
# from csv file  63    3.93158
# Name: y_RD, dtype: float64
# from json file  3.9315800349561694
# from csv file  17    3.16589
# Name: y_RD, dtype: float64
# from json file  3.165887517113263
# from csv file  135    4.329
# Name: y_RD, dtype: float64
# from json file  4.328998977546343
# from csv file  126    3.60127
# Name: y_RD, dtype: float64
# from json file  3.6012691272462423
# from csv file  177    3.36698
# Name: y_RD, dtype: float64
# from json file  3.3669751696782892
# from csv file  172    4.45314
# Name: y_RD, dtype: float64
# from json file  4.453136537923846
# from csv file  76    4.783
# Name: y_RD, dtype: float64
# from json file  4.782997901685063
# from csv file  67    4.60254
# Name: y_RD, dtype: float64
# from json file  4.602537659860869
# from csv file  21    6.66784
# Name: y_RD, dtype: float64
# from json file  6.6678355985428945
# from csv file  139    3.91215
# Name: y_RD, dtype: float64
# from json file  3.912147834750694
# from csv file  130    4.56102
# Name: y_RD, dtype: float64
# from json file  4.561016158069087
# from csv file  185    3.44035
# Name: y_RD, dtype: float64
# from json file  3.440347921954766
# from csv file  181    4.77245
# Name: y_RD, dtype: float64
# from json file  4.772447630319631
# from csv file  175    5.97661
# Name: y_RD, dtype: float64
# from json file  5.976605632949857
# from csv file  79    4.86758
# Name: y_RD, dtype: float64
# from json file  4.8675840489710565
# from csv file  71    3.50577
# Name: y_RD, dtype: float64
# from json file  3.505772871116339
# from csv file  33    2.79231
# Name: y_RD, dtype: float64
# from json file  2.7923120581192657
# from csv file  25    2.95094
# Name: y_RD, dtype: float64
# from json file  2.950938167552816
# from csv file  147    4.76731
# Name: y_RD, dtype: float64
# from json file  4.767311905437836
# from csv file  143    3.89801
# Name: y_RD, dtype: float64
# from json file  3.8980104919386025
# from csv file  132    1.81596
# Name: y_RD, dtype: float64
# from json file  1.8159567864853434
# from csv file  187    3.54272
# Name: y_RD, dtype: float64
# from json file  3.5427160181415194
# from csv file  184    6.90718
# Name: y_RD, dtype: float64
# from json file  6.9071763673326005
# from csv file  91    2.85106
# Name: y_RD, dtype: float64
# from json file  2.851062055663112
# from csv file  83    2.3664
# Name: y_RD, dtype: float64
# from json file  2.366397957456713
# from csv file  73    3.41574
# Name: y_RD, dtype: float64
# from json file  3.4157411289462614
# from csv file  37    3.2254
# Name: y_RD, dtype: float64
# from json file  3.225400318320696
# from csv file  94    1.93073
# Name: y_RD, dtype: float64
# from json file  1.9307275103714545
# from csv file  87    3.40049
# Name: y_RD, dtype: float64
# from json file  3.400489641998545
# from csv file  51    2.07856
# Name: y_RD, dtype: float64
# from json file  2.07855904920727
# from csv file  41    3.4982
# Name: y_RD, dtype: float64
# from json file  3.498202552237606
# from csv file  55    1.56577
# Name: y_RD, dtype: float64
# from json file  1.565770795370414
# from csv file  44    0.836164
# Name: y_RD, dtype: float64
# from json file  0.836163624108743
# from csv file  102    7.29526
# Name: y_RD, dtype: float64
# from json file  7.295260964799639
# from csv file  154    5.48615
# Name: y_RD, dtype: float64
# from json file  5.486148043223709
# from csv file  118    9.19715
# Name: y_RD, dtype: float64
# from json file  9.19714892994857
# from csv file  107    6.77342
# Name: y_RD, dtype: float64
# from json file  6.77341971011
# from csv file  165    6.245
# Name: y_RD, dtype: float64
# from json file  6.244996704065357
# from csv file  158    4.50594
# Name: y_RD, dtype: float64
# from json file  4.505936070585413
# from csv file  122    2.84846
# Name: y_RD, dtype: float64
# from json file  2.848458199557446
# from csv file  112    4.21936
# Name: y_RD, dtype: float64
# from json file  4.219364263063228
# from csv file  169    5.09123
# Name: y_RD, dtype: float64
# from json file  5.091229581445238
# from csv file  162    4.72152
# Name: y_RD, dtype: float64
# from json file  4.721519905397147
# from csv file  64    3.09534
# Name: y_RD, dtype: float64
# from json file  3.095343872438853
# from csv file  136    5.79473
# Name: y_RD, dtype: float64
# from json file  5.7947292086125115
# from csv file  127    3.06445
# Name: y_RD, dtype: float64
# from json file  3.0644457292789906
# from csv file  114    3.96231
# Name: y_RD, dtype: float64
# from json file  3.962309646409684
# from csv file  178    4.08782
# Name: y_RD, dtype: float64
# from json file  4.087823083757815
# from csv file  173    5.45712
# Name: y_RD, dtype: float64
# from json file  5.457123406936269
# from csv file  68    7.27214
# Name: y_RD, dtype: float64
# from json file  7.272135128627926
# from csv file  140    4.84594
# Name: y_RD, dtype: float64
# from json file  4.845939686331151
# from csv file  131    4.65044
# Name: y_RD, dtype: float64
# from json file  4.650435283755294
# from csv file  182    5.50713
# Name: y_RD, dtype: float64
# from json file  5.507133631598589
# from csv file  80    3.38059
# Name: y_RD, dtype: float64
# from json file  3.380594188595137
# from csv file  72    4.1586
# Name: y_RD, dtype: float64
# from json file  4.158596377905179
# from csv file  84    2.56939
# Name: y_RD, dtype: float64
# from json file  2.5693859994797035
# from csv file  103    5.54432
# Name: y_RD, dtype: float64
# from json file  5.5443174314811134
# from csv file  155    8.71879
# Name: y_RD, dtype: float64
# from json file  8.718792598642354
# from csv file  108    5.83804
# Name: y_RD, dtype: float64
# from json file  5.838037372217028
# from csv file  166    2.85762
# Name: y_RD, dtype: float64
# from json file  2.8576160664810453
# from csv file  159    6.49743
# Name: y_RD, dtype: float64
# from json file  6.497430610855276
# from csv file  123    6.14358
# Name: y_RD, dtype: float64
# from json file  6.143580563770168
# from csv file  113    4.69573
# Name: y_RD, dtype: float64
# from json file  4.695729106525577
# from csv file  170    6.12839
# Name: y_RD, dtype: float64
# from json file  6.128391808810903
# from csv file  128    4.9369
# Name: y_RD, dtype: float64
# from json file  4.936897170242408
# from csv file  179    2.61053
# Name: y_RD, dtype: float64
# from json file  2.6105269120993397
# from csv file  174    5.6526
# Name: y_RD, dtype: float64
# from json file  5.652604529935542
# from csv file  109    3.28067
# Name: y_RD, dtype: float64
# from json file  3.2806683221845967
# from csv file  160    6.16488
# Name: y_RD, dtype: float64
# from json file  6.164875857538432
# from csv file  204    4.14843
# Name: y_RD, dtype: float64
# from json file  4.148427963604491
# from csv file  209    3.41047
# Name: y_RD, dtype: float64
# from json file  3.4104679735677546
# from csv file  240    0.419238
# Name: y_RD, dtype: float64
# from json file  0.419238470721512
# from csv file  189    4.42754
# Name: y_RD, dtype: float64
# from json file  4.427540474982856
# from csv file  245    5.9547
# Name: y_RD, dtype: float64
# from json file  5.954696006933741
# from csv file  201    4.31169
# Name: y_RD, dtype: float64
# from json file  4.311690710612695
# from csv file  193    3.74158
# Name: y_RD, dtype: float64
# from json file  3.7415792877542735
# from csv file  259    4.37073
# Name: y_RD, dtype: float64
# from json file  4.370727533170583
# from csv file  250    9.01607
# Name: y_RD, dtype: float64
# from json file  9.016066601065221
# from csv file  205    3.74861
# Name: y_RD, dtype: float64
# from json file  3.748608183968178
# from csv file  197    4.72036
# Name: y_RD, dtype: float64
# from json file  4.72036262008413
# from csv file  262    2.48865
# Name: y_RD, dtype: float64
# from json file  2.488651987600863
# from csv file  221    4.47932
# Name: y_RD, dtype: float64
# from json file  4.4793231556368625
# from csv file  210    5.26919
# Name: y_RD, dtype: float64
# from json file  5.269187340715602
# from csv file  275    3.14579
# Name: y_RD, dtype: float64
# from json file  3.1457884554215205
# from csv file  267    5.19775
# Name: y_RD, dtype: float64
# from json file  5.197749118919213
# from csv file  224    3.75392
# Name: y_RD, dtype: float64
# from json file  3.7539150541469817
# from csv file  215    4.67035
# Name: y_RD, dtype: float64
# from json file  4.670353116135169
# from csv file  279    4.73627
# Name: y_RD, dtype: float64
# from json file  4.736270754267233
# from csv file  234    2.73482
# Name: y_RD, dtype: float64
# from json file  2.734818227291354
# from csv file  228    3.37329
# Name: y_RD, dtype: float64
# from json file  3.3732916358796263
# from csv file  291    3.22583
# Name: y_RD, dtype: float64
# from json file  3.2258277789760337
# from csv file  283    2.74743
# Name: y_RD, dtype: float64
# from json file  2.7474288253392665
# from csv file  237    2.80357
# Name: y_RD, dtype: float64
# from json file  2.803566699884738
# from csv file  231    2.51886
# Name: y_RD, dtype: float64
# from json file  2.518855230568163
# from csv file  294    1.6246
# Name: y_RD, dtype: float64
# from json file  1.624596290907948
# from csv file  287    3.41283
# Name: y_RD, dtype: float64
# from json file  3.412826203022351
# from csv file  241    3.04559
# Name: y_RD, dtype: float64
# from json file  3.0455889895133113
# from csv file  188    6.39312
# Name: y_RD, dtype: float64
# from json file  6.393122766439507
# from csv file  333    4.28401
# Name: y_RD, dtype: float64
# from json file  4.284014825240127
# from csv file  243    9.42901
# Name: y_RD, dtype: float64
# from json file  9.429010514800792
# from csv file  190    5.37526
# Name: y_RD, dtype: float64
# from json file  5.3752579827969615
# from csv file  299    7.02478
# Name: y_RD, dtype: float64
# from json file  7.024781931762246
# from csv file  334    6.21007
# Name: y_RD, dtype: float64
# from json file  6.210074713577494
# from csv file  246    5.14037
# Name: y_RD, dtype: float64
# from json file  5.1403722951631
# from csv file  202    6.19164
# Name: y_RD, dtype: float64
# from json file  6.191639512753721
# from csv file  194    4.80054
# Name: y_RD, dtype: float64
# from json file  4.800542320501188
# from csv file  309    3.57382
# Name: y_RD, dtype: float64
# from json file  3.5738185932500626
# from csv file  303    4.70179
# Name: y_RD, dtype: float64
# from json file  4.701786210425505
# from csv file  338    1.99944
# Name: y_RD, dtype: float64
# from json file  1.9994396493016908
# from csv file  260    4.67606
# Name: y_RD, dtype: float64
# from json file  4.676061053785631
# from csv file  251    5.00635
# Name: y_RD, dtype: float64
# from json file  5.006346845147864
# from csv file  206    5.88639
# Name: y_RD, dtype: float64
# from json file  5.8863869328402485
# from csv file  198    4.56778
# Name: y_RD, dtype: float64
# from json file  4.567782205896169
# from csv file  313    3.75623
# Name: y_RD, dtype: float64
# from json file  3.756232478814272
# from csv file  345    2.98547
# Name: y_RD, dtype: float64
# from json file  2.9854683707342087
# from csv file  263    6.12135
# Name: y_RD, dtype: float64
# from json file  6.1213458573806
# from csv file  255    8.80912
# Name: y_RD, dtype: float64
# from json file  8.809121055933913
# from csv file  222    3.53765
# Name: y_RD, dtype: float64
# from json file  3.537651487901449
# from csv file  211    4.62463
# Name: y_RD, dtype: float64
# from json file  4.624631853540364
# from csv file  321    4.04549
# Name: y_RD, dtype: float64
# from json file  4.045486147879966
# from csv file  317    5.5822
# Name: y_RD, dtype: float64
# from json file  5.582196364951322
# from csv file  353    3.20636
# Name: y_RD, dtype: float64
# from json file  3.206364741497576
# from csv file  349    2.90993
# Name: y_RD, dtype: float64
# from json file  2.909930879455615
# from csv file  276    3.90579
# Name: y_RD, dtype: float64
# from json file  3.9057862881449714
# from csv file  268    3.68975
# Name: y_RD, dtype: float64
# from json file  3.689750981508434
# from csv file  225    3.75688
# Name: y_RD, dtype: float64
# from json file  3.7568781006041454
# from csv file  216    3.61476
# Name: y_RD, dtype: float64
# from json file  3.6147594954032436
# from csv file  329    4.45244
# Name: y_RD, dtype: float64
# from json file  4.452442748733226
# from csv file  324    4.79327
# Name: y_RD, dtype: float64
# from json file  4.793271296832435
# from csv file  320    1.83878
# Name: y_RD, dtype: float64
# from json file  1.838781780389424
# from csv file  356    4.74681
# Name: y_RD, dtype: float64
# from json file  4.74680775314766
# from csv file  290    3.11427
# Name: y_RD, dtype: float64
# from json file  3.1142727781701285
# from csv file  280    3.35898
# Name: y_RD, dtype: float64
# from json file  3.358978225977254
# from csv file  272    3.24472
# Name: y_RD, dtype: float64
# from json file  3.2447199273393714
# from csv file  235    4.71387
# Name: y_RD, dtype: float64
# from json file  4.713870689227228
# from csv file  229    3.3068
# Name: y_RD, dtype: float64
# from json file  3.3067993903934854
# from csv file  219    1.42559
# Name: y_RD, dtype: float64
# from json file  1.425589235297375
# from csv file  331    5.72992
# Name: y_RD, dtype: float64
# from json file  5.729915071869511
# from csv file  327    3.11205
# Name: y_RD, dtype: float64
# from json file  3.112053813618998
# from csv file  292    2.71483
# Name: y_RD, dtype: float64
# from json file  2.714829942186586
# from csv file  284    2.9884
# Name: y_RD, dtype: float64
# from json file  2.988402135031669
# from csv file  238    2.77499
# Name: y_RD, dtype: float64
# from json file  2.7749925195567147
# from csv file  232    3.45678
# Name: y_RD, dtype: float64
# from json file  3.4567800599351095
# from csv file  295    2.0803
# Name: y_RD, dtype: float64
# from json file  2.0802973767894257
# from csv file  288    2.2858
# Name: y_RD, dtype: float64
# from json file  2.2858013304744413
# from csv file  242    1.05467
# Name: y_RD, dtype: float64
# from json file  1.054672994266798
# from csv file  297    5.4697
# Name: y_RD, dtype: float64
# from json file  5.469701338952664
# from csv file  244    7.99978
# Name: y_RD, dtype: float64
# from json file  7.9997786738027505
# from csv file  191    4.01656
# Name: y_RD, dtype: float64
# from json file  4.016556276981054
# from csv file  300    6.37525
# Name: y_RD, dtype: float64
# from json file  6.375249971496823
# from csv file  335    6.83116
# Name: y_RD, dtype: float64
# from json file  6.831161940799103
# from csv file  247    4.93244
# Name: y_RD, dtype: float64
# from json file  4.932441912228901
# from csv file  203    2.01035
# Name: y_RD, dtype: float64
# from json file  2.0103487749344735
# from csv file  195    5.29881
# Name: y_RD, dtype: float64
# from json file  5.298809695302928
# from csv file  310    5.28457
# Name: y_RD, dtype: float64
# from json file  5.284573441010594
# from csv file  304    7.29305
# Name: y_RD, dtype: float64
# from json file  7.293053755702104
# from csv file  342    5.18511
# Name: y_RD, dtype: float64
# from json file  5.185108081196832
# from csv file  339    4.45962
# Name: y_RD, dtype: float64
# from json file  4.459619412715854
# from csv file  261    7.36887
# Name: y_RD, dtype: float64
# from json file  7.368865736377138
# from csv file  252    5.28862
# Name: y_RD, dtype: float64
# from json file  5.288617255874123
# from csv file  207    3.87599
# Name: y_RD, dtype: float64
# from json file  3.8759910852137165
# from csv file  199    5.84923
# Name: y_RD, dtype: float64
# from json file  5.849231891450783
# from csv file  314    4.40125
# Name: y_RD, dtype: float64
# from json file  4.4012549580703055
# from csv file  306    4.80851
# Name: y_RD, dtype: float64
# from json file  4.808511612697934
# from csv file  346    2.84121
# Name: y_RD, dtype: float64
# from json file  2.8412083470965457
# from csv file  264    3.7959
# Name: y_RD, dtype: float64
# from json file  3.795898671635432
# from csv file  256    4.82843
# Name: y_RD, dtype: float64
# from json file  4.828425062446327
# from csv file  223    3.74748
# Name: y_RD, dtype: float64
# from json file  3.7474751733481413
# from csv file  212    3.87998
# Name: y_RD, dtype: float64
# from json file  3.879980783255629
# from csv file  322    4.29115
# Name: y_RD, dtype: float64
# from json file  4.291151590183895
# from csv file  318    4.0564
# Name: y_RD, dtype: float64
# from json file  4.056400722467052
# from csv file  354    4.49313
# Name: y_RD, dtype: float64
# from json file  4.4931290582112595
# from csv file  350    4.05074
# Name: y_RD, dtype: float64
# from json file  4.050735083450046
# from csv file  277    3.57296
# Name: y_RD, dtype: float64
# from json file  3.5729638166595223
# from csv file  269    4.398
# Name: y_RD, dtype: float64
# from json file  4.397996268149962
# from csv file  226    4.36536
# Name: y_RD, dtype: float64
# from json file  4.365360059953593
# from csv file  217    4.19935
# Name: y_RD, dtype: float64
# from json file  4.199347146478087
# from csv file  330    4.06642
# Name: y_RD, dtype: float64
# from json file  4.066418973779754
# from csv file  325    3.00358
# Name: y_RD, dtype: float64
# from json file  3.003578716960626
# from csv file  357    2.76902
# Name: y_RD, dtype: float64
# from json file  2.7690163438682607
# from csv file  355    3.1286
# Name: y_RD, dtype: float64
# from json file  3.1285996056184
# from csv file  281    3.85722
# Name: y_RD, dtype: float64
# from json file  3.8572192837351684
# from csv file  273    3.7134
# Name: y_RD, dtype: float64
# from json file  3.7133957703978204
# from csv file  236    2.14869
# Name: y_RD, dtype: float64
# from json file  2.148685239840999
# from csv file  230    2.71842
# Name: y_RD, dtype: float64
# from json file  2.718423368309033
# from csv file  220    2.82937
# Name: y_RD, dtype: float64
# from json file  2.8293696473258425
# from csv file  332    4.40123
# Name: y_RD, dtype: float64
# from json file  4.401229233672694
# from csv file  328    4.57202
# Name: y_RD, dtype: float64
# from json file  4.572023749767665
# from csv file  293    2.2941
# Name: y_RD, dtype: float64
# from json file  2.294098164150779
# from csv file  285    3.37312
# Name: y_RD, dtype: float64
# from json file  3.373124800790284
# from csv file  239    7.05385
# Name: y_RD, dtype: float64
# from json file  7.053850562779079
# from csv file  233    3.3544
# Name: y_RD, dtype: float64
# from json file  3.3544019654927153
# from csv file  296    1.1829
# Name: y_RD, dtype: float64
# from json file  1.1829013895651068
# from csv file  289    6.32746
# Name: y_RD, dtype: float64
# from json file  6.3274551554605205
# from csv file  298    6.42614
# Name: y_RD, dtype: float64
# from json file  6.426135373780307
# from csv file  192    4.73638
# Name: y_RD, dtype: float64
# from json file  4.7363802057318
# from csv file  301    5.82619
# Name: y_RD, dtype: float64
# from json file  5.826185204848323
# from csv file  336    5.79161
# Name: y_RD, dtype: float64
# from json file  5.791608624141555
# from csv file  248    4.87748
# Name: y_RD, dtype: float64
# from json file  4.877484969557995
# from csv file  196    5.26435
# Name: y_RD, dtype: float64
# from json file  5.264354336051722
# from csv file  311    7.04545
# Name: y_RD, dtype: float64
# from json file  7.045452057801109
# from csv file  305    6.10644
# Name: y_RD, dtype: float64
# from json file  6.106439728761708
# from csv file  343    5.61265
# Name: y_RD, dtype: float64
# from json file  5.612647173962926
# from csv file  340    5.04955
# Name: y_RD, dtype: float64
# from json file  5.049551238017083
# from csv file  253    5.33618
# Name: y_RD, dtype: float64
# from json file  5.336179039560686
# from csv file  208    3.83059
# Name: y_RD, dtype: float64
# from json file  3.830586282962679
# from csv file  200    3.27412
# Name: y_RD, dtype: float64
# from json file  3.2741210536147207
# from csv file  315    4.68681
# Name: y_RD, dtype: float64
# from json file  4.686806241822551
# from csv file  307    7.37771
# Name: y_RD, dtype: float64
# from json file  7.377706810273492
# from csv file  352    1.4597
# Name: y_RD, dtype: float64
# from json file  1.4597029010935676
# from csv file  347    5.49385
# Name: y_RD, dtype: float64
# from json file  5.493853828296241
# from csv file  265    2.98358
# Name: y_RD, dtype: float64
# from json file  2.983583087977305
# from csv file  257    5.42062
# Name: y_RD, dtype: float64
# from json file  5.420616360051889
# from csv file  213    3.62257
# Name: y_RD, dtype: float64
# from json file  3.622567942104735
# from csv file  323    5.2233
# Name: y_RD, dtype: float64
# from json file  5.223301897111612
# from csv file  319    5.0432
# Name: y_RD, dtype: float64
# from json file  5.043201183451248
# from csv file  351    8.45465
# Name: y_RD, dtype: float64
# from json file  8.454646297421435
# from csv file  278    2.58819
# Name: y_RD, dtype: float64
# from json file  2.588188856950416
# from csv file  270    4.83746
# Name: y_RD, dtype: float64
# from json file  4.837462763938816
# from csv file  227    3.8394
# Name: y_RD, dtype: float64
# from json file  3.839399567308396
# from csv file  218    2.87795
# Name: y_RD, dtype: float64
# from json file  2.87795227377404
# from csv file  326    3.90531
# Name: y_RD, dtype: float64
# from json file  3.9053069031231042
# from csv file  282    4.38184
# Name: y_RD, dtype: float64
# from json file  4.381837792912781
# from csv file  274    5.64335
# Name: y_RD, dtype: float64
# from json file  5.643345689997228
# from csv file  286    3.31104
# Name: y_RD, dtype: float64
# from json file  3.311044477016892
# from csv file  337    8.07454
# Name: y_RD, dtype: float64
# from json file  8.074539656757802
# from csv file  249    3.88738
# Name: y_RD, dtype: float64
# from json file  3.8873776342862736
# from csv file  312    3.61536
# Name: y_RD, dtype: float64
# from json file  3.6153594488358496
# from csv file  344    7.35379
# Name: y_RD, dtype: float64
# from json file  7.353786704468575
# from csv file  341    8.4871
# Name: y_RD, dtype: float64
# from json file  8.487103942160736
# from csv file  254    8.97817
# Name: y_RD, dtype: float64
# from json file  8.978167211704646
# from csv file  316    4.49993
# Name: y_RD, dtype: float64
# from json file  4.499934274705604
# from csv file  308    5.17417
# Name: y_RD, dtype: float64
# from json file  5.174166197213048
# from csv file  348    3.6138
# Name: y_RD, dtype: float64
# from json file  3.613798937999207
# from csv file  266    3.29745
# Name: y_RD, dtype: float64
# from json file  3.2974506730294797
# from csv file  258    6.33258
# Name: y_RD, dtype: float64
# from json file  6.332578219694781
# from csv file  214    4.18364
# Name: y_RD, dtype: float64
# from json file  4.183636017817956
# from csv file  271    2.79449
# Name: y_RD, dtype: float64
# from json file  2.794492222468045
# from csv file  302    3.61626
# Name: y_RD, dtype: float64
# from json file  3.6162605842218873
# from csv file  359    3.70867
# Name: y_RD, dtype: float64
# from json file  3.7086683858565306
# from csv file  363    2.67303
# Name: y_RD, dtype: float64
# from json file  2.673030982659798
# from csv file  387    3.53318
# Name: y_RD, dtype: float64
# from json file  3.533182082865963
# from csv file  391    2.47749
# Name: y_RD, dtype: float64
# from json file  2.47748676950203
# from csv file  403    3.5354
# Name: y_RD, dtype: float64
# from json file  3.5354035814051823
# from csv file  396    1.46299
# Name: y_RD, dtype: float64
# from json file  1.462993141886604
# from csv file  407    1.31778
# Name: y_RD, dtype: float64
# from json file  1.317781763997246
# from csv file  400    0.907192
# Name: y_RD, dtype: float64
# from json file  0.9071924278181502
# from csv file  358    3.74889
# Name: y_RD, dtype: float64
# from json file  3.7488859023541785
# from csv file  360    6.98203
# Name: y_RD, dtype: float64
# from json file  6.982026249541976
# from csv file  371    4.2407
# Name: y_RD, dtype: float64
# from json file  4.240704194200402
# from csv file  364    8.22536
# Name: y_RD, dtype: float64
# from json file  8.225363008771097
# from csv file  413    4.73805
# Name: y_RD, dtype: float64
# from json file  4.738047568723378
# from csv file  373    5.72761
# Name: y_RD, dtype: float64
# from json file  5.727605763376538
# from csv file  367    9.48376
# Name: y_RD, dtype: float64
# from json file  9.48376373195236
# from csv file  425    3.49811
# Name: y_RD, dtype: float64
# from json file  3.498107797228787
# from csv file  418    4.68556
# Name: y_RD, dtype: float64
# from json file  4.685561489940272
# from csv file  388    2.95169
# Name: y_RD, dtype: float64
# from json file  2.9516892399147037
# from csv file  377    6.08012
# Name: y_RD, dtype: float64
# from json file  6.0801154632016905
# from csv file  428    3.68416
# Name: y_RD, dtype: float64
# from json file  3.6841555533048065
# from csv file  392    4.55829
# Name: y_RD, dtype: float64
# from json file  4.558286481526851
# from csv file  381    2.29409
# Name: y_RD, dtype: float64
# from json file  2.2940888288091186
# from csv file  439    2.89273
# Name: y_RD, dtype: float64
# from json file  2.8927307019215958
# from csv file  432    4.84597
# Name: y_RD, dtype: float64
# from json file  4.845966229142753
# from csv file  404    4.11962
# Name: y_RD, dtype: float64
# from json file  4.119624142151795
# from csv file  397    2.16831
# Name: y_RD, dtype: float64
# from json file  2.168312967606312
# from csv file  442    1.61686
# Name: y_RD, dtype: float64
# from json file  1.6168565555420853
# from csv file  436    2.30944
# Name: y_RD, dtype: float64
# from json file  2.30944094901048
# from csv file  408    2.91648
# Name: y_RD, dtype: float64
# from json file  2.9164766384406544
# from csv file  401    2.31515
# Name: y_RD, dtype: float64
# from json file  2.3151546922157147
# from csv file  445    2.71926
# Name: y_RD, dtype: float64
# from json file  2.71925636630561
# from csv file  410    1.55626
# Name: y_RD, dtype: float64
# from json file  1.5562621287795113
# from csv file  361    8.8453
# Name: y_RD, dtype: float64
# from json file  8.84529979747816
# from csv file  446    5.55939
# Name: y_RD, dtype: float64
# from json file  5.5593936250884886
# from csv file  411    6.73759
# Name: y_RD, dtype: float64
# from json file  6.73758785984906
# from csv file  480    3.40747
# Name: y_RD, dtype: float64
# from json file  3.4074717459348007
# from csv file  476    3.4899
# Name: y_RD, dtype: float64
# from json file  3.4899021616982093
# from csv file  372    4.08021
# Name: y_RD, dtype: float64
# from json file  4.080207317599316
# from csv file  365    7.95722
# Name: y_RD, dtype: float64
# from json file  7.957215365451131
# from csv file  449    5.76445
# Name: y_RD, dtype: float64
# from json file  5.7644478053724235
# from csv file  414    4.80355
# Name: y_RD, dtype: float64
# from json file  4.803551093074418
# from csv file  484    2.90888
# Name: y_RD, dtype: float64
# from json file  2.9088778040349395
# from csv file  374    5.30636
# Name: y_RD, dtype: float64
# from json file  5.306357914754433
# from csv file  368    6.92036
# Name: y_RD, dtype: float64
# from json file  6.920355367002797
# from csv file  459    2.63776
# Name: y_RD, dtype: float64
# from json file  2.6377621462677405
# from csv file  453    4.69465
# Name: y_RD, dtype: float64
# from json file  4.694649378890302
# from csv file  426    3.08641
# Name: y_RD, dtype: float64
# from json file  3.0864122140268995
# from csv file  419    3.72619
# Name: y_RD, dtype: float64
# from json file  3.7261916163620583
# from csv file  491    3.48102
# Name: y_RD, dtype: float64
# from json file  3.4810243724452303
# from csv file  487    2.19272
# Name: y_RD, dtype: float64
# from json file  2.1927150875029895
# from csv file  389    2.7776
# Name: y_RD, dtype: float64
# from json file  2.777601101491786
# from csv file  378    5.5886
# Name: y_RD, dtype: float64
# from json file  5.58859626830673
# from csv file  462    3.62682
# Name: y_RD, dtype: float64
# from json file  3.6268224891661456
# from csv file  429    4.59905
# Name: y_RD, dtype: float64
# from json file  4.599048497449275
# from csv file  422    4.62916
# Name: y_RD, dtype: float64
# from json file  4.629164517148071
# from csv file  493    2.55602
# Name: y_RD, dtype: float64
# from json file  2.556019639713412
# from csv file  393    3.20604
# Name: y_RD, dtype: float64
# from json file  3.2060356157161
# from csv file  382    3.59495
# Name: y_RD, dtype: float64
# from json file  3.594952708072598
# from csv file  468    2.21707
# Name: y_RD, dtype: float64
# from json file  2.2170686702515816
# from csv file  465    3.41806
# Name: y_RD, dtype: float64
# from json file  3.4180589636431633
# from csv file  440    3.0298
# Name: y_RD, dtype: float64
# from json file  3.029804762173705
# from csv file  433    2.40223
# Name: y_RD, dtype: float64
# from json file  2.402233430359581
# from csv file  405    2.7866
# Name: y_RD, dtype: float64
# from json file  2.786596400392936
# from csv file  398    2.98399
# Name: y_RD, dtype: float64
# from json file  2.9839892565354704
# from csv file  385    1.35719
# Name: y_RD, dtype: float64
# from json file  1.3571932821672816
# from csv file  470    7.58945
# Name: y_RD, dtype: float64
# from json file  7.5894503919039105
# from csv file  467    2.37509
# Name: y_RD, dtype: float64
# from json file  2.3750851245856954
# from csv file  443    3.32996
# Name: y_RD, dtype: float64
# from json file  3.329964736951836
# from csv file  437    4.43252
# Name: y_RD, dtype: float64
# from json file  4.432523231745745
# from csv file  409    3.23221
# Name: y_RD, dtype: float64
# from json file  3.2322098200677574
# from csv file  402    1.91197
# Name: y_RD, dtype: float64
# from json file  1.9119679639150704
# from csv file  471    4.27804
# Name: y_RD, dtype: float64
# from json file  4.278044748720597
# from csv file  473    5.76323
# Name: y_RD, dtype: float64
# from json file  5.763229688153607
# from csv file  362    8.38738
# Name: y_RD, dtype: float64
# from json file  8.387380593883266
# from csv file  447    8.79388
# Name: y_RD, dtype: float64
# from json file  8.79388058289903
# from csv file  412    5.05625
# Name: y_RD, dtype: float64
# from json file  5.05624810911645
# from csv file  481    4.57085
# Name: y_RD, dtype: float64
# from json file  4.570850274264935
# from csv file  477    5.65878
# Name: y_RD, dtype: float64
# from json file  5.658783916622161
# from csv file  366    6.77852
# Name: y_RD, dtype: float64
# from json file  6.77851609997598
# from csv file  450    4.16835
# Name: y_RD, dtype: float64
# from json file  4.168351426283013
# from csv file  415    7.30317
# Name: y_RD, dtype: float64
# from json file  7.303170756354264
# from csv file  490    1.2551
# Name: y_RD, dtype: float64
# from json file  1.255099868050415
# from csv file  485    5.67844
# Name: y_RD, dtype: float64
# from json file  5.678443818686935
# from csv file  375    3.1694
# Name: y_RD, dtype: float64
# from json file  3.1694034719975734
# from csv file  369    4.77484
# Name: y_RD, dtype: float64
# from json file  4.7748407500833
# from csv file  460    3.21722
# Name: y_RD, dtype: float64
# from json file  3.217219269528265
# from csv file  454    4.87933
# Name: y_RD, dtype: float64
# from json file  4.879328453285791
# from csv file  427    5.63455
# Name: y_RD, dtype: float64
# from json file  5.634554977993325
# from csv file  420    4.16811
# Name: y_RD, dtype: float64
# from json file  4.168111858256537
# from csv file  492    3.02559
# Name: y_RD, dtype: float64
# from json file  3.0255872082180115
# from csv file  488    6.2012
# Name: y_RD, dtype: float64
# from json file  6.201202954073479
# from csv file  390    1.84382
# Name: y_RD, dtype: float64
# from json file  1.843823575344294
# from csv file  379    4.62677
# Name: y_RD, dtype: float64
# from json file  4.626773427143413
# from csv file  463    2.98862
# Name: y_RD, dtype: float64
# from json file  2.9886155874791736
# from csv file  457    8.43438
# Name: y_RD, dtype: float64
# from json file  8.434382321908087
# from csv file  430    2.90613
# Name: y_RD, dtype: float64
# from json file  2.906133424118361
# from csv file  423    6.4329
# Name: y_RD, dtype: float64
# from json file  6.432902146594074
# from csv file  494    2.69148
# Name: y_RD, dtype: float64
# from json file  2.6914814374474774
# from csv file  394    4.18709
# Name: y_RD, dtype: float64
# from json file  4.18708526235318
# from csv file  383    3.0724
# Name: y_RD, dtype: float64
# from json file  3.072398903839139
# from csv file  469    3.96861
# Name: y_RD, dtype: float64
# from json file  3.9686143074770825
# from csv file  466    4.76574
# Name: y_RD, dtype: float64
# from json file  4.765744027652225
# from csv file  441    4.03164
# Name: y_RD, dtype: float64
# from json file  4.0316405153532155
# from csv file  434    2.98766
# Name: y_RD, dtype: float64
# from json file  2.987659611027777
# from csv file  406    2.88604
# Name: y_RD, dtype: float64
# from json file  2.8860356559375884
# from csv file  399    3.22972
# Name: y_RD, dtype: float64
# from json file  3.2297176486861385
# from csv file  386    2.74221
# Name: y_RD, dtype: float64
# from json file  2.74221172551277
# from csv file  444    6.72188
# Name: y_RD, dtype: float64
# from json file  6.72187732265546
# from csv file  438    4.21177
# Name: y_RD, dtype: float64
# from json file  4.211768419763036
# from csv file  472    5.68862
# Name: y_RD, dtype: float64
# from json file  5.6886194254143785
# from csv file  474    7.46938
# Name: y_RD, dtype: float64
# from json file  7.469378544060445
# from csv file  448    4.91809
# Name: y_RD, dtype: float64
# from json file  4.91808745312422
# from csv file  482    6.65963
# Name: y_RD, dtype: float64
# from json file  6.659627562091506
# from csv file  478    7.23594
# Name: y_RD, dtype: float64
# from json file  7.235936531086376
# from csv file  451    5.61031
# Name: y_RD, dtype: float64
# from json file  5.610313786986798
# from csv file  416    3.81392
# Name: y_RD, dtype: float64
# from json file  3.8139235766468182
# from csv file  486    4.20843
# Name: y_RD, dtype: float64
# from json file  4.208428898415306
# from csv file  479    4.62679
# Name: y_RD, dtype: float64
# from json file  4.626785925463576
# from csv file  376    2.66759
# Name: y_RD, dtype: float64
# from json file  2.6675852283161676
# from csv file  370    4.26135
# Name: y_RD, dtype: float64
# from json file  4.261349058516547
# from csv file  461    3.68532
# Name: y_RD, dtype: float64
# from json file  3.6853226463486286
# from csv file  455    4.75438
# Name: y_RD, dtype: float64
# from json file  4.754377113993808
# from csv file  421    5.34088
# Name: y_RD, dtype: float64
# from json file  5.340875888174518
# from csv file  489    3.83006
# Name: y_RD, dtype: float64
# from json file  3.830062163866293
# from csv file  380    3.75277
# Name: y_RD, dtype: float64
# from json file  3.7527711973483746
# from csv file  464    4.04684
# Name: y_RD, dtype: float64
# from json file  4.046839585164271
# from csv file  458    8.32785
# Name: y_RD, dtype: float64
# from json file  8.32785398366739
# from csv file  431    3.03223
# Name: y_RD, dtype: float64
# from json file  3.032225170715775
# from csv file  424    4.45836
# Name: y_RD, dtype: float64
# from json file  4.458362679832711
# from csv file  395    4.99681
# Name: y_RD, dtype: float64
# from json file  4.996808884620292
# from csv file  384    2.55606
# Name: y_RD, dtype: float64
# from json file  2.5560576855673895
# from csv file  435    3.5661
# Name: y_RD, dtype: float64
# from json file  3.5661000721512512
# from csv file  475    6.87104
# Name: y_RD, dtype: float64
# from json file  6.8710445510239415
# from csv file  483    6.86489
# Name: y_RD, dtype: float64
# from json file  6.864887186424274
# from csv file  452    6.93766
# Name: y_RD, dtype: float64
# from json file  6.937661044110082
# from csv file  417    2.92128
# Name: y_RD, dtype: float64
# from json file  2.9212790975522673
# from csv file  456    3.15147
# Name: y_RD, dtype: float64
# from json file  3.151465440663114
