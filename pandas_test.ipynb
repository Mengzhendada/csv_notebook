# %%
import pandas as pd
pd.read_csv('campass/HEPData-ins1444985-v1-Table_1.csv',header = 13)
# Out:
#       0.0087  0.004  0.01  0.443  0.3  0.5   1.149  0.223   0.2  0.25  1.8171  \
# 0     0.0088  0.004  0.01  0.435  0.3  0.5   1.138  0.274  0.25   0.3  1.2272
# 1     0.0088  0.004  0.01  0.435  0.3  0.5   1.138  0.324   0.3  0.35  0.9095
# 2     0.0088  0.004  0.01  0.435  0.3  0.5   1.138  0.374  0.35   0.4  0.6308
# 3     0.0088  0.004  0.01  0.435  0.3  0.5   1.138  0.424   0.4  0.45  0.4661
# 4     0.0088  0.004  0.01  0.432  0.3  0.5   1.132  0.474  0.45   0.5  0.3585
# ...      ...    ...   ...    ...  ...  ...     ...    ...   ...   ...     ...
# 1561    0.25   0.18   0.4  0.378  0.3  0.5  28.146  0.474  0.45   0.5  0.9623
# 1562    0.25   0.18   0.4  0.366  0.3  0.5  27.209  0.524   0.5  0.55  0.9631
# 1563  0.2501   0.18   0.4  0.353  0.3  0.5  26.174  0.574  0.55   0.6  0.9643
# 1564  0.2501   0.18   0.4   0.34  0.3  0.5  25.228  0.624   0.6  0.65  0.9656
# 1565  0.2502   0.18   0.4  0.329  0.3  0.5  24.339  0.674  0.65   0.7  0.9669
#
#       0.0155  -0.0155  0.0913  -0.0913
# 0     0.0125  -0.0125  0.0615  -0.0615
# 1     0.0112  -0.0112  0.0455  -0.0455
# 2     0.0095  -0.0095  0.0317  -0.0317
# 3     0.0084  -0.0084  0.0236  -0.0236
# 4     0.0079  -0.0079  0.0187  -0.0187
# ...      ...      ...     ...      ...
# 1561     NaN      NaN     NaN      NaN
# 1562     NaN      NaN     NaN      NaN
# 1563     NaN      NaN     NaN      NaN
# 1564     NaN      NaN     NaN      NaN
# 1565     NaN      NaN     NaN      NaN
#
# [1566 rows x 15 columns]

# %%
pd.read_csv("csv.csv")
# Out:
#       Q2  Q2_corr    xbj  xbj_corr      z    z_corr  RunGroup     y_RD  \
# 0    4.0  3.41255  0.275  0.287134  0.375  0.373686       100  4.91852
# 1    4.0  3.78059  0.325  0.325361  0.375  0.376769       100  5.96769
# 2    4.0  4.21210  0.375  0.370503  0.375  0.380197       100  6.83378
# 3    4.0  4.60704  0.425  0.416890  0.375  0.385148       100  3.27669
# 4    4.0  3.40661  0.275  0.286871  0.425  0.423565       100  5.64060
# ..   ...      ...    ...       ...    ...       ...       ...      ...
# 417  5.5  5.05713  0.575  0.559636  0.475  0.461397       440  6.22381
# 418  5.5  4.52165  0.475  0.490784  0.525  0.520660       440  2.47591
# 419  5.5  4.70073  0.525  0.514611  0.525  0.511987       440  5.50647
# 420  5.5  4.51366  0.475  0.490004  0.525  0.522165       430  4.98203
# 421  5.5  4.69927  0.525  0.512883  0.525  0.514540       430  7.01965
#
#      error_RD  y_RD_rho  ...  yield_pos_rho  yield_neg_incnorad  \
# 0    1.038160   4.49105  ...       0.734042           18.027700
# 1    0.814457   5.58730  ...       1.479320           42.939200
# 2    1.225780   6.60667  ...       0.542809           22.966200
# 3    0.971830   3.15986  ...       0.123056            4.625790
# 4    1.175430   5.33572  ...       0.411638           14.396300
# ..        ...       ...  ...            ...                 ...
# 417  2.865240   5.70476  ...       0.022115            0.672278
# 418  0.905703   2.28809  ...       0.013666            0.426895
# 419  2.126920   4.58414  ...       0.048494            0.690022
# 420  2.471640   4.38778  ...       0.025718            0.471048
# 421  3.804530   6.59735  ...       0.038343            0.745427
#
#      yield_neg_incrad  yield_pos_incnorad  yield_pos_incrad  W2_corr  \
# 0           16.920200           26.680200         25.882100  9.35832
# 1           39.463700           64.626400         62.366500  8.72627
# 2           20.580600           35.092500         32.245300  8.04359
# 3            4.080890            7.152000          6.064220  7.32982
# 4           14.290800           21.782900         22.783000  9.35477
# ..                ...                 ...               ...      ...
# 417          0.548426            1.093420          0.993549  4.86149
# 418          0.360904            0.717380          0.609120  5.57471
# 419          0.545119            1.159380          1.029140  5.31697
# 420          0.400119            0.793639          0.812509  5.58150
# 421          0.609679            1.255950          0.929769  5.34591
#
#      Wp2_corr  xprime_corr  zprime_corr   shms_p
# 0     6.10197     0.281077     0.365131  2.36843
# 1     5.68119     0.317242     0.366963  2.33427
# 2     5.22116     0.359668     0.368969  2.30425
# 3     4.72658     0.403937     0.372821  2.26924
# 4     5.67586     0.280734     0.414115  2.68345
# ..        ...          ...          ...      ...
# 417   2.85158          NaN          NaN  2.22268
# 418   2.93939     0.469458     0.498227  2.55841
# 419   2.86246          NaN          NaN  2.49426
# 420   2.93988     0.468933     0.500556  2.56555
# 421   2.86678     0.458751     0.458111  2.51435
#
# [422 rows x 25 columns]

# %%
df = pd.read_csv("csv.csv")

# %%
df.head()
# Out:
#     Q2  Q2_corr    xbj  xbj_corr      z    z_corr  RunGroup     y_RD  \
# 0  4.0  3.41255  0.275  0.287134  0.375  0.373686       100  4.91852
# 1  4.0  3.78059  0.325  0.325361  0.375  0.376769       100  5.96769
# 2  4.0  4.21210  0.375  0.370503  0.375  0.380197       100  6.83378
# 3  4.0  4.60704  0.425  0.416890  0.375  0.385148       100  3.27669
# 4  4.0  3.40661  0.275  0.286871  0.425  0.423565       100  5.64060
#
#    error_RD  y_RD_rho  ...  yield_pos_rho  yield_neg_incnorad  \
# 0  1.038160   4.49105  ...       0.734042            18.02770
# 1  0.814457   5.58730  ...       1.479320            42.93920
# 2  1.225780   6.60667  ...       0.542809            22.96620
# 3  0.971830   3.15986  ...       0.123056             4.62579
# 4  1.175430   5.33572  ...       0.411638            14.39630
#
#    yield_neg_incrad  yield_pos_incnorad  yield_pos_incrad  W2_corr  Wp2_corr  \
# 0          16.92020             26.6802          25.88210  9.35832   6.10197
# 1          39.46370             64.6264          62.36650  8.72627   5.68119
# 2          20.58060             35.0925          32.24530  8.04359   5.22116
# 3           4.08089              7.1520           6.06422  7.32982   4.72658
# 4          14.29080             21.7829          22.78300  9.35477   5.67586
#
#    xprime_corr  zprime_corr   shms_p
# 0     0.281077     0.365131  2.36843
# 1     0.317242     0.366963  2.33427
# 2     0.359668     0.368969  2.30425
# 3     0.403937     0.372821  2.26924
# 4     0.280734     0.414115  2.68345
#
# [5 rows x 25 columns]

# %%
df.describe()
# Out:
#                Q2     Q2_corr         xbj    xbj_corr           z      z_corr  \
# count  422.000000  422.000000  422.000000  422.000000  422.000000  422.000000
# mean     4.662915    4.397734    0.438033    0.438509    0.508531    0.507515
# std      0.599856    0.659834    0.073967    0.069900    0.094919    0.091078
# min      4.000000    3.168080    0.275000    0.284332    0.325000    0.337271
# 25%      4.000000    3.871925    0.375000    0.382175    0.425000    0.432767
# 50%      4.750000    4.405945    0.425000    0.429493    0.525000    0.515047
# 75%      5.500000    4.885587    0.475000    0.478371    0.575000    0.573083
# max      5.500000    6.084450    0.625000    0.612932    0.775000    0.756395
#
#          RunGroup        y_RD    error_RD    y_RD_rho  ...  yield_pos_rho  \
# count  422.000000  422.000000  422.000000  422.000000  ...     422.000000
# mean   289.312796    4.441767    1.225026    3.987303  ...       0.466707
# std    149.433616    1.671094    0.802808    1.660834  ...       0.523783
# min     70.000000    0.850512    0.260150    0.041173  ...       0.000647
# 25%    160.000000    3.254392    0.685325    2.810402  ...       0.117711
# 50%    280.000000    4.257675    0.971796    3.837050  ...       0.266186
# 75%    437.500000    5.404682    1.467442    4.975157  ...       0.598856
# max    550.000000    9.995050    4.728050    9.539320  ...       3.253490
#
#        yield_neg_incnorad  yield_neg_incrad  yield_pos_incnorad  \
# count          422.000000        422.000000          422.000000
# mean             8.616091          7.498220           13.927978
# std              8.384337          7.423834           13.329187
# min              0.122590          0.130895            0.213873
# 25%              2.495335          2.168825            4.152772
# 50%              5.681400          4.885215            9.074540
# 75%             12.030800         10.808150           19.207725
# max             43.136600         41.519800           66.392700
#
#        yield_pos_incrad     W2_corr    Wp2_corr  xprime_corr  zprime_corr  \
# count        422.000000  422.000000  422.000000   407.000000   407.000000
# mean          12.281470    6.588146    3.506014     0.418320     0.486338
# std           11.923199    1.114605    0.610096     0.063461     0.089918
# min            0.210288    4.342340    2.842820     0.272870     0.323902
# 25%            3.601608    5.731805    3.005445     0.367766     0.412711
# 50%            7.964640    6.422375    3.315555     0.413166     0.471022
# 75%           17.395175    7.374140    3.825215     0.458120     0.551542
# max           63.484600    9.417340    6.101970     0.545692     0.740563
#
#            shms_p
# count  422.000000
# mean     2.754830
# std      0.665270
# min      1.563990
# 25%      2.236498
# 50%      2.671880
# 75%      3.214363
# max      4.815340
#
# [8 rows x 25 columns]

# %%
#for row in df.itertuples():
#    print(row.Q2_corr)

# %%
pd.value_counts(df['Q2']).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['Q2_corr'].mean()
# Out:
# 4.397734028436019

# %%
df.groupby(['Q2']).mean()
# Out:
#        Q2_corr       xbj  xbj_corr         z    z_corr    RunGroup      y_RD  \
# Q2
# 4.00  3.810017  0.387963  0.387710  0.524383  0.523522  209.320988  4.572458
# 4.75  4.518408  0.454592  0.455130  0.498129  0.496973  226.326531  4.486181
# 5.50  5.083319  0.488274  0.489714  0.499336  0.498281  485.929204  4.196628
#
#       error_RD  y_RD_rho  yield_neg  ...  yield_pos_rho  yield_neg_incnorad  \
# Q2                                   ...
# 4.00  1.224573  4.032568  11.067475  ...       0.859415           14.547582
# 4.75  1.221773  4.045924   4.938458  ...       0.299313            6.579717
# 5.50  1.229905  3.846150   2.213976  ...       0.121470            2.761624
#
#       yield_neg_incrad  yield_pos_incnorad  yield_pos_incrad   W2_corr  \
# Q2
# 4.00         12.690907           23.413040         20.669949  7.042586
# 4.75          5.715170           10.673543          9.419228  6.353233
# 5.50          2.373380            4.563570          3.978957  6.242243
#
#       Wp2_corr  xprime_corr  zprime_corr    shms_p
# Q2
# 4.00  3.642171     0.372789     0.504659  2.811881
# 4.75  3.453418     0.434693     0.474241  2.664257
# 5.50  3.379237     0.466451     0.474495  2.790866
#
# [3 rows x 24 columns]

# %%
df[df['Q2']<4.85].groupby(['Q2','xbj','z']).describe() #sooooooooooo simple way to group!!!!!!!!!
# Out:
#                  Q2_corr                                                   \
#                    count      mean       std      min       25%       50%
# Q2   xbj   z
# 4.00 0.275 0.375     1.0  3.412550       NaN  3.41255  3.412550  3.412550
#            0.425     1.0  3.406610       NaN  3.40661  3.406610  3.406610
#            0.475     2.0  3.410080  0.000311  3.40986  3.409970  3.410080
#            0.525     2.0  3.412050  0.001556  3.41095  3.411500  3.412050
#            0.575     2.0  3.414200  0.003451  3.41176  3.412980  3.414200
# ...                  ...       ...       ...      ...       ...       ...
# 4.75 0.525 0.525     5.0  5.051980  0.281380  4.70137  4.811960  5.136610
#            0.575     4.0  5.242532  0.053880  5.17240  5.222313  5.247655
#      0.575 0.375     3.0  5.091147  0.401811  4.75174  4.869315  4.986890
#            0.425     2.0  4.959815  0.245048  4.78654  4.873177  4.959815
#            0.475     3.0  5.357173  0.243976  5.08031  5.265405  5.450500
#
#                                     xbj_corr            ... zprime_corr  \
#                        75%      max    count      mean  ...         75%
# Q2   xbj   z                                            ...
# 4.00 0.275 0.375  3.412550  3.41255      1.0  0.287134  ...    0.365131
#            0.425  3.406610  3.40661      1.0  0.286871  ...    0.414115
#            0.475  3.410190  3.41030      2.0  0.288128  ...    0.459383
#            0.525  3.412600  3.41315      2.0  0.286881  ...    0.519420
#            0.575  3.415420  3.41664      2.0  0.288026  ...    0.559569
# ...                    ...      ...      ...       ...  ...         ...
# 4.75 0.525 0.525  5.282830  5.32713      5.0  0.517434  ...    0.499705
#            0.575  5.267875  5.30242      4.0  0.511763  ...    0.530382
#      0.575 0.375  5.260850  5.53481      3.0  0.569986  ...    0.361601
#            0.425  5.046453  5.13309      2.0  0.563619  ...    0.398130
#            0.475  5.495605  5.54071      3.0  0.562990  ...    0.445381
#
#                            shms_p                                         \
#                        max  count      mean       std      min       25%
# Q2   xbj   z
# 4.00 0.275 0.375  0.365131    1.0  2.368430       NaN  2.36843  2.368430
#            0.425  0.414115    1.0  2.683450       NaN  2.68345  2.683450
#            0.475  0.463816    2.0  2.937235  0.094660  2.87030  2.903767
#            0.525  0.521590    2.0  3.352530  0.045934  3.32005  3.336290
#            0.575  0.562307    2.0  3.601150  0.058831  3.55955  3.580350
# ...                    ...    ...       ...       ...      ...       ...
# 4.75 0.525 0.525  0.514100    5.0  2.723124  0.178160  2.50789  2.584460
#            0.575  0.536145    4.0  3.089853  0.055397  3.01969  3.067945
#      0.575 0.375  0.365939    3.0  1.802780  0.168364  1.65924  1.710120
#            0.425  0.412932    2.0  1.999040  0.179039  1.87244  1.935740
#            0.475  0.447703    3.0  2.381897  0.123349  2.25008  2.325580
#
#
#                        50%       75%      max
# Q2   xbj   z
# 4.00 0.275 0.375  2.368430  2.368430  2.36843
#            0.425  2.683450  2.683450  2.68345
#            0.475  2.937235  2.970702  3.00417
#            0.525  3.352530  3.368770  3.38501
#            0.575  3.601150  3.621950  3.64275
# ...                    ...       ...      ...
# 4.75 0.525 0.525  2.744460  2.836220  2.94259
#            0.575  3.092885  3.114793  3.15395
#      0.575 0.375  1.761000  1.874550  1.98810
#            0.425  1.999040  2.062340  2.12564
#            0.475  2.401080  2.447805  2.49453
#
# [77 rows x 176 columns]

# %%
import json
grouped_df = df.groupby(['Q2','xbj','z'])
gb = grouped_df.groups
data = []
group_num = 10
for key in gb.keys():
    print(key)
    print(key[1])
    RunGroups = df[df['Q2']==key[0]][df['xbj']==key[1]][df['z']==key[2]]['RunGroup']
    for i in RunGroups:
        print(i)
    #data = {group_num:{'Q2':key[0],'xbj':key[1],'z':key[2],'RunGroups':RunGroups}}
    group_num = group_num+10
    #print(json.dumps(data, indent=4))
    #print(df[df['Q2']==key[0]][df['xbj']==key[1]][df['z']==key[2]]['RunGroup'])
# Out:
# (4.0, 0.275, 0.375)
# 0.275
# 100
# (4.0, 0.275, 0.425)
# 0.275
# 100
# (4.0, 0.275, 0.475)
# 0.275
# 100
# 90
# (4.0, 0.275, 0.525)
# 0.275
# 90
# 80
# (4.0, 0.275, 0.575)
# 0.275
# 90
# 80
# (4.0, 0.275, 0.625)
# 0.275
# 80
# 70
# (4.0, 0.275, 0.675)
# 0.275
# 80
# 70
# (4.0, 0.275, 0.725)
# 0.275
# 70
# (4.0, 0.275, 0.775)
# 0.275
# 70
# (4.0, 0.325, 0.325)
# 0.325
# 140
# (4.0, 0.325, 0.375)
# 0.325
# 100
# (4.0, 0.325, 0.425)
# 0.325
# 100
# 90
# 400
# 140
# 130
# (4.0, 0.325, 0.475)
# 0.325
# 100
# 90
# 400
# 130
# (4.0, 0.325, 0.525)
# 0.325
# 90
# 80
# 400
# 390
# 130
# 120
# (4.0, 0.325, 0.575)
# 0.325
# 90
# 80
# 400
# 390
# 120
# (4.0, 0.325, 0.625)
# 0.325
# 80
# 70
# 390
# 380
# 120
# (4.0, 0.325, 0.675)
# 0.325
# 80
# 70
# 390
# 380
# (4.0, 0.325, 0.725)
# 0.325
# 80
# 70
# 380
# (4.0, 0.375, 0.325)
# 0.375
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_7417/1856077749.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   RunGroups = df[df['Q2']==key[0]][df['xbj']==key[1]][df['z']==key[2]]['RunGroup']
# 140
# 350
# (4.0, 0.375, 0.375)
# 0.375
# 100
# 140
# 350
# (4.0, 0.375, 0.425)
# 0.375
# 100
# 400
# 140
# 130
# 350
# 340
# (4.0, 0.375, 0.475)
# 0.375
# 100
# 90
# 400
# 140
# 130
# 340
# (4.0, 0.375, 0.525)
# 0.375
# 90
# 80
# 400
# 390
# 130
# 120
# 340
# 330
# (4.0, 0.375, 0.575)
# 0.375
# 90
# 80
# 400
# 390
# 120
# 110
# 330
# (4.0, 0.375, 0.625)
# 0.375
# 90
# 80
# 70
# 390
# 380
# 120
# 110
# (4.0, 0.375, 0.675)
# 0.375
# 80
# 70
# 390
# 380
# (4.0, 0.375, 0.725)
# 0.375
# 80
# 70
# (4.0, 0.425, 0.325)
# 0.425
# 140
# 350
# (4.0, 0.425, 0.375)
# 0.425
# 100
# 140
# 350
# (4.0, 0.425, 0.425)
# 0.425
# 100
# 400
# 140
# 130
# 350
# 340
# (4.0, 0.425, 0.475)
# 0.425
# 100
# 90
# 400
# 140
# 130
# 350
# 340
# (4.0, 0.425, 0.525)
# 0.425
# 90
# 400
# 390
# 130
# 120
# 340
# 330
# (4.0, 0.425, 0.575)
# 0.425
# 90
# 80
# 400
# 390
# 130
# 120
# 340
# 330
# 320
# (4.0, 0.425, 0.625)
# 0.425
# 80
# 400
# 390
# 380
# 120
# 110
# (4.0, 0.425, 0.675)
# 0.425
# 80
# 70
# (4.0, 0.475, 0.375)
# 0.475
# 140
# 350
# (4.0, 0.475, 0.425)
# 0.475
# 140
# 130
# 350
# 340
# (4.0, 0.475, 0.475)
# 0.475
# 400
# 140
# 130
# 350
# 340
# (4.0, 0.475, 0.525)
# 0.475
# 400
# 130
# 120
# 340
# 330
# (4.0, 0.475, 0.575)
# 0.475
# 400
# 390
# 120
# (4.0, 0.525, 0.375)
# 0.525
# 140
# 350
# (4.0, 0.525, 0.425)
# 0.525
# 140
# 350
# 340
# (4.0, 0.525, 0.475)
# 0.525
# 140
# 130
# 340
# (4.75, 0.325, 0.475)
# 0.325
# 170
# (4.75, 0.325, 0.525)
# 0.325
# 170
# (4.75, 0.325, 0.675)
# 0.325
# 150
# (4.75, 0.375, 0.375)
# 0.375
# 180
# 300
# (4.75, 0.375, 0.425)
# 0.375
# 180
# 170
# 300
# 290
# (4.75, 0.375, 0.475)
# 0.375
# 180
# 170
# 290
# (4.75, 0.375, 0.525)
# 0.375
# 170
# 160
# 290
# 280
# (4.75, 0.375, 0.575)
# 0.375
# 170
# 160
# 280
# (4.75, 0.375, 0.625)
# 0.375
# 160
# 150
# 280
# 270
# (4.75, 0.375, 0.675)
# 0.375
# 160
# 150
# 280
# 270
# (4.75, 0.425, 0.325)
# 0.425
# 180
# 220
# 260
# (4.75, 0.425, 0.375)
# 0.425
# 180
# 300
# 220
# 260
# (4.75, 0.425, 0.425)
# 0.425
# 180
# 170
# 300
# 290
# 220
# 210
# 260
# (4.75, 0.425, 0.475)
# 0.425
# 180
# 170
# 300
# 290
# 210
# 250
# (4.75, 0.425, 0.525)
# 0.425
# 170
# 160
# 290
# 280
# 210
# 200
# 250
# 240
# (4.75, 0.425, 0.575)
# 0.425
# 170
# 160
# 290
# 280
# 270
# 210
# 200
# 190
# (4.75, 0.425, 0.625)
# 0.425
# 170
# 160
# 150
# 280
# 270
# 190
# (4.75, 0.425, 0.675)
# 0.425
# 160
# 150
# 280
# 270
# (4.75, 0.475, 0.325)
# 0.475
# 220
# 260
# (4.75, 0.475, 0.375)
# 0.475
# 180
# 300
# 220
# 260
# (4.75, 0.475, 0.425)
# 0.475
# 180
# 170
# 300
# 290
# 220
# 210
# 260
# 250
# (4.75, 0.475, 0.475)
# 0.475
# 180
# 170
# 300
# 290
# 220
# 210
# 250
# (4.75, 0.475, 0.525)
# 0.475
# 170
# 160
# 290
# 280
# 210
# 200
# 250
# 240
# (4.75, 0.475, 0.575)
# 0.475
# 170
# 160
# 290
# 280
# 200
# (4.75, 0.475, 0.625)
# 0.475
# 170
# 160
# 150
# 280
# 270
# (4.75, 0.525, 0.325)
# 0.525
# 220
# (4.75, 0.525, 0.375)
# 0.525
# 180
# 300
# 220
# 260
# (4.75, 0.525, 0.425)
# 0.525
# 180
# 300
# 220
# 210
# 260
# 250
# (4.75, 0.525, 0.475)
# 0.525
# 180
# 170
# 300
# 290
# 220
# 210
# 250
# (4.75, 0.525, 0.525)
# 0.525
# 170
# 290
# 280
# 210
# 200
# (4.75, 0.525, 0.575)
# 0.525
# 170
# 160
# 290
# 280
# (4.75, 0.575, 0.375)
# 0.575
# 300
# 220
# 260
# (4.75, 0.575, 0.425)
# 0.575
# 210
# 260
# (4.75, 0.575, 0.475)
# 0.575
# 300
# 290
# 210
# (5.5, 0.375, 0.375)
# 0.375
# 480
# (5.5, 0.375, 0.425)
# 0.375
# 480
# (5.5, 0.375, 0.525)
# 0.375
# 460
# (5.5, 0.375, 0.575)
# 0.375
# 460
# (5.5, 0.375, 0.625)
# 0.375
# 460
# 360
# (5.5, 0.375, 0.675)
# 0.375
# 460
# 360
# (5.5, 0.425, 0.325)
# 0.425
# 480
# (5.5, 0.425, 0.375)
# 0.425
# 480
# (5.5, 0.425, 0.425)
# 0.425
# 480
# 470
# 550
# (5.5, 0.425, 0.475)
# 0.425
# 480
# 470
# 550
# 540
# (5.5, 0.425, 0.525)
# 0.425
# 470
# 460
# 540
# (5.5, 0.425, 0.575)
# 0.425
# 470
# 460
# 540
# 530
# (5.5, 0.425, 0.625)
# 0.425
# 460
# 360
# 540
# 530
# (5.5, 0.425, 0.675)
# 0.425
# 460
# 360
# (5.5, 0.475, 0.375)
# 0.475
# 480
# 550
# 520
# (5.5, 0.475, 0.425)
# 0.475
# 480
# 470
# 550
# 520
# 450
# 440
# (5.5, 0.475, 0.475)
# 0.475
# 480
# 470
# 550
# 540
# 520
# 510
# 440
# (5.5, 0.475, 0.525)
# 0.475
# 470
# 460
# 550
# 540
# 510
# 440
# 430
# (5.5, 0.475, 0.575)
# 0.475
# 470
# 460
# 540
# 530
# 510
# 500
# (5.5, 0.475, 0.625)
# 0.475
# 470
# 460
# 360
# 540
# 530
# (5.5, 0.475, 0.675)
# 0.475
# 460
# (5.5, 0.525, 0.325)
# 0.525
# 450
# (5.5, 0.525, 0.375)
# 0.525
# 480
# 520
# 450
# (5.5, 0.525, 0.425)
# 0.525
# 480
# 550
# 520
# 450
# 440
# (5.5, 0.525, 0.475)
# 0.525
# 480
# 470
# 550
# 540
# 520
# 510
# 440
# (5.5, 0.525, 0.525)
# 0.525
# 470
# 460
# 550
# 540
# 520
# 510
# 440
# 430
# (5.5, 0.525, 0.575)
# 0.525
# 470
# 460
# 540
# 530
# (5.5, 0.525, 0.625)
# 0.525
# 460
# (5.5, 0.575, 0.325)
# 0.575
# 450
# (5.5, 0.575, 0.375)
# 0.575
# 480
# 520
# 450
# (5.5, 0.575, 0.425)
# 0.575
# 480
# 550
# 520
# 450
# 440
# (5.5, 0.575, 0.475)
# 0.575
# 480
# 470
# 550
# 520
# 510
# 440
# (5.5, 0.575, 0.525)
# 0.575
# 470
# 540
# 510
# (5.5, 0.625, 0.375)
# 0.625
# 450

# %%
import json
with open('yield_ratio_Q2xzRunG_combined.json') as j_RD:
    RDxz = json.load(j_RD)
for key_Q2,Q2_value in RDxz.items():
    Q2 = float(key_Q2)
    #print(Q2)
    for key_xbj,xbj_value in Q2_value.items():
        xbj = float(key_xbj) 
        for key_z,z_value in xbj_value.items():
            z_hadron = float(key_z)
            for key_RunG,RunG_value in z_value.items():
                RunGroup = float(key_RunG)
                RD=float(RunG_value["value"])
                RD_error = float(RunG_value["error"])
                xbj_corr = float(RunG_value["xbj_corr"])
                z_corr = float(RunG_value["z_corr"])
                csv_value = df[df['Q2']==Q2][df['xbj']==xbj][df['z']==z_hadron][df['RunGroup']==RunGroup]['y_RD']
                print('from csv file ',csv_value)
                print('from json file ',RD)
    #plt.savefig("RD_xbj_z_"+str(Q2)+".png")
# Out:
# from csv file  0    4.91852
# Name: y_RD, dtype: float64
# from json file  4.91852296244815
# from csv file  4    5.6406
# Name: y_RD, dtype: float64
# from json file  5.640604589039152
# from csv file  8    1.82308
# Name: y_RD, dtype: float64
# from json file  1.8230807519903582
# from csv file  13    6.79563
# Name: y_RD, dtype: float64
# from json file  6.795632663581849
# from csv file  26    2.25325
# Name: y_RD, dtype: float64
# from json file  2.253253933460645
# from csv file  17    8.96039
# Name: y_RD, dtype: float64
# from json file  8.960393939546147
# from csv file  29    2.88625
# Name: y_RD, dtype: float64
# from json file  2.8862512546208166
# from csv file  21    4.1358
# Name: y_RD, dtype: float64
# from json file  4.135798817047583
# from csv file  43    3.93665
# Name: y_RD, dtype: float64
# from json file  3.936654959090254
# from csv file  33    3.44162
# Name: y_RD, dtype: float64
# from json file  3.441615126195373
# from csv file  46    1.72644
# Name: y_RD, dtype: float64
# from json file  1.726441170463926
# from csv file  37    3.16647
# Name: y_RD, dtype: float64
# from json file  3.1664716999250206
# from csv file  50    2.07482
# Name: y_RD, dtype: float64
# from json file  2.0748159898733243
# from csv file  53    1.98863
# Name: y_RD, dtype: float64
# from json file  1.988629599321598
# from csv file  88    5.25436
# Name: y_RD, dtype: float64
# from json file  5.2543572141026536
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_7417/2193712879.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   csv_value = df[df['Q2']==Q2][df['xbj']==xbj][df['z']==z_hadron][df['RunGroup']==RunGroup]['y_RD']
# from csv file  1    5.96769
# Name: y_RD, dtype: float64
# from json file  5.967685616364282
# from csv file  5    4.59586
# Name: y_RD, dtype: float64
# from json file  4.595861831757772
# from csv file  104    3.51909
# Name: y_RD, dtype: float64
# from json file  3.5190911149569764
# from csv file  95    4.47321
# Name: y_RD, dtype: float64
# from json file  4.473210091198588
# from csv file  54    5.56863
# Name: y_RD, dtype: float64
# from json file  5.568631068586491
# from csv file  12    8.12312
# Name: y_RD, dtype: float64
# from json file  8.123124778135992
# from csv file  9    5.823
# Name: y_RD, dtype: float64
# from json file  5.823000500129804
# from csv file  108    3.8368
# Name: y_RD, dtype: float64
# from json file  3.83679881871269
# from csv file  57    5.00492
# Name: y_RD, dtype: float64
# from json file  5.004921012507991
# from csv file  14    5.46239
# Name: y_RD, dtype: float64
# from json file  5.462386054898471
# from csv file  118    3.77851
# Name: y_RD, dtype: float64
# from json file  3.778509966732238
# from csv file  113    6.39454
# Name: y_RD, dtype: float64
# from json file  6.394535387944072
# from csv file  70    5.83787
# Name: y_RD, dtype: float64
# from json file  5.83787273091178
# from csv file  61    4.39055
# Name: y_RD, dtype: float64
# from json file  4.390554590802284
# from csv file  27    4.34773
# Name: y_RD, dtype: float64
# from json file  4.347727883701284
# from csv file  18    4.45565
# Name: y_RD, dtype: float64
# from json file  4.455651480861115
# from csv file  122    9.27798
# Name: y_RD, dtype: float64
# from json file  9.277979569649114
# from csv file  73    3.9882
# Name: y_RD, dtype: float64
# from json file  3.9882020608952145
# from csv file  65    4.12194
# Name: y_RD, dtype: float64
# from json file  4.121938362775955
# from csv file  30    4.00371
# Name: y_RD, dtype: float64
# from json file  4.00370558156232
# from csv file  22    3.54536
# Name: y_RD, dtype: float64
# from json file  3.5453554893796047
# from csv file  126    4.20177
# Name: y_RD, dtype: float64
# from json file  4.201772275413189
# from csv file  82    2.7414
# Name: y_RD, dtype: float64
# from json file  2.7413956527235253
# from csv file  77    4.86077
# Name: y_RD, dtype: float64
# from json file  4.860774715997272
# from csv file  44    2.23968
# Name: y_RD, dtype: float64
# from json file  2.2396750514149106
# from csv file  34    3.97707
# Name: y_RD, dtype: float64
# from json file  3.977072978144526
# from csv file  85    3.26892
# Name: y_RD, dtype: float64
# from json file  3.2689219763820985
# from csv file  80    3.15722
# Name: y_RD, dtype: float64
# from json file  3.1572227469797784
# from csv file  47    2.36024
# Name: y_RD, dtype: float64
# from json file  2.3602441508659826
# from csv file  38    2.14098
# Name: y_RD, dtype: float64
# from json file  2.1409811815199737
# from csv file  87    4.4911
# Name: y_RD, dtype: float64
# from json file  4.491097701258991
# from csv file  51    1.97914
# Name: y_RD, dtype: float64
# from json file  1.9791399103882925
# from csv file  41    4.65556
# Name: y_RD, dtype: float64
# from json file  4.655555482685474
# from csv file  89    4.07344
# Name: y_RD, dtype: float64
# from json file  4.073443582739769
# from csv file  132    6.58991
# Name: y_RD, dtype: float64
# from json file  6.589909849455135
# from csv file  2    6.83378
# Name: y_RD, dtype: float64
# from json file  6.833781330400501
# from csv file  91    4.4558
# Name: y_RD, dtype: float64
# from json file  4.455804671608396
# from csv file  134    5.33349
# Name: y_RD, dtype: float64
# from json file  5.333490457001238
# from csv file  6    4.13678
# Name: y_RD, dtype: float64
# from json file  4.136780368087322
# from csv file  105    3.44873
# Name: y_RD, dtype: float64
# from json file  3.4487268281012295
# from csv file  96    7.33802
# Name: y_RD, dtype: float64
# from json file  7.338015864967009
# from csv file  144    4.2883
# Name: y_RD, dtype: float64
# from json file  4.288298724546487
# from csv file  138    6.29352
# Name: y_RD, dtype: float64
# from json file  6.293516916582205
# from csv file  55    8.75941
# Name: y_RD, dtype: float64
# from json file  8.759406178412119
# from csv file  10    4.90601
# Name: y_RD, dtype: float64
# from json file  4.906009014858448
# from csv file  109    4.68138
# Name: y_RD, dtype: float64
# from json file  4.6813831709507685
# from csv file  100    4.00862
# Name: y_RD, dtype: float64
# from json file  4.008616284586908
# from csv file  148    3.34324
# Name: y_RD, dtype: float64
# from json file  3.3432383702648805
# from csv file  58    4.28365
# Name: y_RD, dtype: float64
# from json file  4.283647275013959
# from csv file  15    4.45886
# Name: y_RD, dtype: float64
# from json file  4.458864770981875
# from csv file  119    6.19051
# Name: y_RD, dtype: float64
# from json file  6.190508948352486
# from csv file  114    3.41661
# Name: y_RD, dtype: float64
# from json file  3.4166071010464845
# from csv file  156    6.00402
# Name: y_RD, dtype: float64
# from json file  6.004023079972565
# from csv file  152    7.21396
# Name: y_RD, dtype: float64
# from json file  7.213964984907872
# from csv file  71    6.19691
# Name: y_RD, dtype: float64
# from json file  6.19690531959533
# from csv file  62    5.13268
# Name: y_RD, dtype: float64
# from json file  5.132680858605659
# from csv file  28    3.08453
# Name: y_RD, dtype: float64
# from json file  3.08452822788085
# from csv file  19    6.23928
# Name: y_RD, dtype: float64
# from json file  6.239280451592538
# from csv file  129    4.513
# Name: y_RD, dtype: float64
# from json file  4.513000959672098
# from csv file  123    3.95078
# Name: y_RD, dtype: float64
# from json file  3.9507774266852906
# from csv file  159    6.03934
# Name: y_RD, dtype: float64
# from json file  6.039340516528624
# from csv file  74    3.92156
# Name: y_RD, dtype: float64
# from json file  3.9215608903274695
# from csv file  66    5.8569
# Name: y_RD, dtype: float64
# from json file  5.856900180763819
# from csv file  31    3.62575
# Name: y_RD, dtype: float64
# from json file  3.6257519301136427
# from csv file  23    3.99866
# Name: y_RD, dtype: float64
# from json file  3.99865605684381
# from csv file  130    5.12123
# Name: y_RD, dtype: float64
# from json file  5.121225262751442
# from csv file  127    3.34191
# Name: y_RD, dtype: float64
# from json file  3.3419055186177316
# from csv file  83    4.75935
# Name: y_RD, dtype: float64
# from json file  4.759354814969341
# from csv file  78    2.76436
# Name: y_RD, dtype: float64
# from json file  2.76436424628272
# from csv file  45    2.18753
# Name: y_RD, dtype: float64
# from json file  2.1875289966794784
# from csv file  35    2.61819
# Name: y_RD, dtype: float64
# from json file  2.618190270036006
# from csv file  25    2.70015
# Name: y_RD, dtype: float64
# from json file  2.7001469705254295
# from csv file  86    3.55681
# Name: y_RD, dtype: float64
# from json file  3.5568081021042475
# from csv file  81    2.89594
# Name: y_RD, dtype: float64
# from json file  2.8959423560679314
# from csv file  48    2.62742
# Name: y_RD, dtype: float64
# from json file  2.6274168614798743
# from csv file  39    2.50149
# Name: y_RD, dtype: float64
# from json file  2.5014901253289445
# from csv file  52    2.4199
# Name: y_RD, dtype: float64
# from json file  2.4199022875109266
# from csv file  42    6.40902
# Name: y_RD, dtype: float64
# from json file  6.409022058573116
# from csv file  90    7.03446
# Name: y_RD, dtype: float64
# from json file  7.034457444112845
# from csv file  133    7.31146
# Name: y_RD, dtype: float64
# from json file  7.311458401918343
# from csv file  3    3.27669
# Name: y_RD, dtype: float64
# from json file  3.276688699590884
# from csv file  92    4.88442
# Name: y_RD, dtype: float64
# from json file  4.884415358889386
# from csv file  135    6.53531
# Name: y_RD, dtype: float64
# from json file  6.53531362919262
# from csv file  7    5.81822
# Name: y_RD, dtype: float64
# from json file  5.818218059082367
# from csv file  106    3.12178
# Name: y_RD, dtype: float64
# from json file  3.121779150043877
# from csv file  97    5.4645
# Name: y_RD, dtype: float64
# from json file  5.464498960673231
# from csv file  145    5.7549
# Name: y_RD, dtype: float64
# from json file  5.754897466537938
# from csv file  139    6.73186
# Name: y_RD, dtype: float64
# from json file  6.731860028082491
# from csv file  56    5.11404
# Name: y_RD, dtype: float64
# from json file  5.1140370252734275
# from csv file  11    4.48429
# Name: y_RD, dtype: float64
# from json file  4.484285131040954
# from csv file  110    3.76196
# Name: y_RD, dtype: float64
# from json file  3.7619631317118314
# from csv file  101    5.37477
# Name: y_RD, dtype: float64
# from json file  5.374772831023731
# from csv file  149    5.07206
# Name: y_RD, dtype: float64
# from json file  5.072061438258663
# from csv file  142    4.96112
# Name: y_RD, dtype: float64
# from json file  4.961115171942879
# from csv file  59    3.83776
# Name: y_RD, dtype: float64
# from json file  3.8377565891427468
# from csv file  16    3.27088
# Name: y_RD, dtype: float64
# from json file  3.270878912284699
# from csv file  120    4.05491
# Name: y_RD, dtype: float64
# from json file  4.0549066515865
# from csv file  115    3.55194
# Name: y_RD, dtype: float64
# from json file  3.551938949025005
# from csv file  157    3.18697
# Name: y_RD, dtype: float64
# from json file  3.1869652903297268
# from csv file  153    4.24409
# Name: y_RD, dtype: float64
# from json file  4.244091171119585
# from csv file  72    4.46353
# Name: y_RD, dtype: float64
# from json file  4.463533413529987
# from csv file  63    4.43457
# Name: y_RD, dtype: float64
# from json file  4.434566699966246
# from csv file  20    6.42641
# Name: y_RD, dtype: float64
# from json file  6.426413766030317
# from csv file  124    3.69792
# Name: y_RD, dtype: float64
# from json file  3.697920899086048
# from csv file  117    4.86092
# Name: y_RD, dtype: float64
# from json file  4.8609184138344865
# from csv file  161    3.532
# Name: y_RD, dtype: float64
# from json file  3.532002094551005
# from csv file  160    3.35043
# Name: y_RD, dtype: float64
# from json file  3.350428842920171
# from csv file  155    5.78204
# Name: y_RD, dtype: float64
# from json file  5.78203606283634
# from csv file  75    4.80664
# Name: y_RD, dtype: float64
# from json file  4.806642792351172
# from csv file  67    3.49689
# Name: y_RD, dtype: float64
# from json file  3.4968911199334625
# from csv file  32    2.90798
# Name: y_RD, dtype: float64
# from json file  2.90797596655317
# from csv file  24    3.26499
# Name: y_RD, dtype: float64
# from json file  3.2649937867508245
# from csv file  131    2.16245
# Name: y_RD, dtype: float64
# from json file  2.162453034133472
# from csv file  128    3.98613
# Name: y_RD, dtype: float64
# from json file  3.9861290538700267
# from csv file  84    3.07145
# Name: y_RD, dtype: float64
# from json file  3.071454072273257
# from csv file  79    2.46796
# Name: y_RD, dtype: float64
# from json file  2.467955823046651
# from csv file  69    5.13493
# Name: y_RD, dtype: float64
# from json file  5.134931185665163
# from csv file  36    3.14395
# Name: y_RD, dtype: float64
# from json file  3.1439494578559057
# from csv file  49    2.66297
# Name: y_RD, dtype: float64
# from json file  2.662970530986824
# from csv file  40    3.62721
# Name: y_RD, dtype: float64
# from json file  3.6272054742301503
# from csv file  93    6.92575
# Name: y_RD, dtype: float64
# from json file  6.925750485484689
# from csv file  136    5.60241
# Name: y_RD, dtype: float64
# from json file  5.6024081188635755
# from csv file  107    7.44866
# Name: y_RD, dtype: float64
# from json file  7.4486597043159755
# from csv file  98    7.14675
# Name: y_RD, dtype: float64
# from json file  7.1467537903784395
# from csv file  146    6.99614
# Name: y_RD, dtype: float64
# from json file  6.996137427783936
# from csv file  140    4.41534
# Name: y_RD, dtype: float64
# from json file  4.4153362593668275
# from csv file  111    3.00185
# Name: y_RD, dtype: float64
# from json file  3.001851289857916
# from csv file  102    4.4006
# Name: y_RD, dtype: float64
# from json file  4.400601993957606
# from csv file  150    4.40916
# Name: y_RD, dtype: float64
# from json file  4.4091645998676245
# from csv file  143    4.54969
# Name: y_RD, dtype: float64
# from json file  4.549687702427405
# from csv file  60    3.21345
# Name: y_RD, dtype: float64
# from json file  3.2134549694444434
# from csv file  121    6.47637
# Name: y_RD, dtype: float64
# from json file  6.476365905611138
# from csv file  116    2.83691
# Name: y_RD, dtype: float64
# from json file  2.8369127451164458
# from csv file  158    4.4968
# Name: y_RD, dtype: float64
# from json file  4.4967991469304724
# from csv file  154    4.62804
# Name: y_RD, dtype: float64
# from json file  4.628040164680104
# from csv file  64    7.20211
# Name: y_RD, dtype: float64
# from json file  7.202112310847361
# from csv file  125    5.57262
# Name: y_RD, dtype: float64
# from json file  5.572617340829492
# from csv file  76    3.75623
# Name: y_RD, dtype: float64
# from json file  3.7562288617361816
# from csv file  68    3.77323
# Name: y_RD, dtype: float64
# from json file  3.7732335858276
# from csv file  94    5.70857
# Name: y_RD, dtype: float64
# from json file  5.708573072870035
# from csv file  137    8.03227
# Name: y_RD, dtype: float64
# from json file  8.032273377088805
# from csv file  99    6.05593
# Name: y_RD, dtype: float64
# from json file  6.05593108433723
# from csv file  147    2.47375
# Name: y_RD, dtype: float64
# from json file  2.473749256165421
# from csv file  141    8.75652
# Name: y_RD, dtype: float64
# from json file  8.756523737017304
# from csv file  112    5.21117
# Name: y_RD, dtype: float64
# from json file  5.211170556946204
# from csv file  103    4.92035
# Name: y_RD, dtype: float64
# from json file  4.920353499457583
# from csv file  151    6.48392
# Name: y_RD, dtype: float64
# from json file  6.483915975316096
# from csv file  178    4.00689
# Name: y_RD, dtype: float64
# from json file  4.006887904929584
# from csv file  183    2.89054
# Name: y_RD, dtype: float64
# from json file  2.8905381398645416
# from csv file  209    1.11973
# Name: y_RD, dtype: float64
# from json file  1.1197276220973795
# from csv file  163    4.31549
# Name: y_RD, dtype: float64
# from json file  4.315494576373795
# from csv file  212    5.8648
# Name: y_RD, dtype: float64
# from json file  5.864803657403693
# from csv file  175    4.09056
# Name: y_RD, dtype: float64
# from json file  4.090561496867009
# from csv file  167    3.7341
# Name: y_RD, dtype: float64
# from json file  3.734101064182554
# from csv file  225    4.67187
# Name: y_RD, dtype: float64
# from json file  4.671872112730642
# from csv file  217    9.91629
# Name: y_RD, dtype: float64
# from json file  9.916286742419503
# from csv file  179    3.8184
# Name: y_RD, dtype: float64
# from json file  3.818403348060841
# from csv file  171    5.15855
# Name: y_RD, dtype: float64
# from json file  5.158545126541604
# from csv file  228    2.23951
# Name: y_RD, dtype: float64
# from json file  2.2395137540882977
# from csv file  194    4.63289
# Name: y_RD, dtype: float64
# from json file  4.632889430822083
# from csv file  184    5.41128
# Name: y_RD, dtype: float64
# from json file  5.4112755716910375
# from csv file  240    3.15708
# Name: y_RD, dtype: float64
# from json file  3.1570841684603606
# from csv file  233    5.25301
# Name: y_RD, dtype: float64
# from json file  5.253008932933527
# from csv file  197    3.88268
# Name: y_RD, dtype: float64
# from json file  3.8826774212073873
# from csv file  188    4.44697
# Name: y_RD, dtype: float64
# from json file  4.446970283677571
# from csv file  244    4.5617
# Name: y_RD, dtype: float64
# from json file  4.561700129087394
# from csv file  206    2.72541
# Name: y_RD, dtype: float64
# from json file  2.725405382660975
# from csv file  201    3.47693
# Name: y_RD, dtype: float64
# from json file  3.4769327619940125
# from csv file  254    3.39169
# Name: y_RD, dtype: float64
# from json file  3.391694023185407
# from csv file  248    2.64795
# Name: y_RD, dtype: float64
# from json file  2.6479480992759985
# from csv file  210    3.45284
# Name: y_RD, dtype: float64
# from json file  3.4528390622397787
# from csv file  204    2.90101
# Name: y_RD, dtype: float64
# from json file  2.9010130601796864
# from csv file  257    1.08344
# Name: y_RD, dtype: float64
# from json file  1.0834400594900873
# from csv file  251    3.31993
# Name: y_RD, dtype: float64
# from json file  3.3199284489834193
# from csv file  162    6.05671
# Name: y_RD, dtype: float64
# from json file  6.056712685048903
# from csv file  259    9.99505
# Name: y_RD, dtype: float64
# from json file  9.995053266394212
# from csv file  290    5.12517
# Name: y_RD, dtype: float64
# from json file  5.125170715628688
# from csv file  164    5.16479
# Name: y_RD, dtype: float64
# from json file  5.164786180374594
# from csv file  262    6.75419
# Name: y_RD, dtype: float64
# from json file  6.754189631566698
# from csv file  292    6.72893
# Name: y_RD, dtype: float64
# from json file  6.728930175084746
# from csv file  213    5.1806
# Name: y_RD, dtype: float64
# from json file  5.180596889617695
# from csv file  176    5.71481
# Name: y_RD, dtype: float64
# from json file  5.714807476617634
# from csv file  168    4.79334
# Name: y_RD, dtype: float64
# from json file  4.793343884321471
# from csv file  271    3.66228
# Name: y_RD, dtype: float64
# from json file  3.6622849738037426
# from csv file  266    4.61455
# Name: y_RD, dtype: float64
# from json file  4.614551723462122
# from csv file  296    2.09437
# Name: y_RD, dtype: float64
# from json file  2.0943701699455137
# from csv file  226    4.43303
# Name: y_RD, dtype: float64
# from json file  4.433031603072295
# from csv file  218    4.88632
# Name: y_RD, dtype: float64
# from json file  4.886322736078382
# from csv file  180    5.64855
# Name: y_RD, dtype: float64
# from json file  5.648552805767486
# from csv file  172    4.36121
# Name: y_RD, dtype: float64
# from json file  4.3612078880328164
# from csv file  275    3.80981
# Name: y_RD, dtype: float64
# from json file  3.8098105696882856
# from csv file  302    2.87796
# Name: y_RD, dtype: float64
# from json file  2.877964661224778
# from csv file  229    5.88228
# Name: y_RD, dtype: float64
# from json file  5.882281909384032
# from csv file  221    8.84578
# Name: y_RD, dtype: float64
# from json file  8.845780292528895
# from csv file  195    3.51083
# Name: y_RD, dtype: float64
# from json file  3.5108302011772836
# from csv file  185    4.63486
# Name: y_RD, dtype: float64
# from json file  4.634858764810521
# from csv file  283    3.87084
# Name: y_RD, dtype: float64
# from json file  3.8708420914703194
# from csv file  279    6.07361
# Name: y_RD, dtype: float64
# from json file  6.073610579357816
# from csv file  307    3.0397
# Name: y_RD, dtype: float64
# from json file  3.039704990739783
# from csv file  305    3.05828
# Name: y_RD, dtype: float64
# from json file  3.058281228290616
# from csv file  241    3.99555
# Name: y_RD, dtype: float64
# from json file  3.9955527761994185
# from csv file  234    3.8324
# Name: y_RD, dtype: float64
# from json file  3.832401504121588
# from csv file  198    3.86272
# Name: y_RD, dtype: float64
# from json file  3.8627175898300643
# from csv file  189    3.66176
# Name: y_RD, dtype: float64
# from json file  3.6617573896891984
# from csv file  288    3.78915
# Name: y_RD, dtype: float64
# from json file  3.789154758983751
# from csv file  286    4.78302
# Name: y_RD, dtype: float64
# from json file  4.783020975429522
# from csv file  282    1.78083
# Name: y_RD, dtype: float64
# from json file  1.7808271458425289
# from csv file  253    3.13989
# Name: y_RD, dtype: float64
# from json file  3.1398858819620012
# from csv file  245    3.60326
# Name: y_RD, dtype: float64
# from json file  3.6032639738902046
# from csv file  237    3.32011
# Name: y_RD, dtype: float64
# from json file  3.3201089864705904
# from csv file  207    5.18186
# Name: y_RD, dtype: float64
# from json file  5.181861912406892
# from csv file  202    3.83653
# Name: y_RD, dtype: float64
# from json file  3.8365250219045066
# from csv file  192    1.36752
# Name: y_RD, dtype: float64
# from json file  1.3675238787360906
# from csv file  289    3.49455
# Name: y_RD, dtype: float64
# from json file  3.494546397209394
# from csv file  255    3.12643
# Name: y_RD, dtype: float64
# from json file  3.126434231720936
# from csv file  249    3.1769
# Name: y_RD, dtype: float64
# from json file  3.1769010690438066
# from csv file  211    5.18161
# Name: y_RD, dtype: float64
# from json file  5.181611537947904
# from csv file  205    6.27466
# Name: y_RD, dtype: float64
# from json file  6.274657823229681
# from csv file  258    2.14548
# Name: y_RD, dtype: float64
# from json file  2.1454802494725853
# from csv file  252    2.01278
# Name: y_RD, dtype: float64
# from json file  2.0127825630216885
# from csv file  260    5.78353
# Name: y_RD, dtype: float64
# from json file  5.783525677291159
# from csv file  291    9.9168
# Name: y_RD, dtype: float64
# from json file  9.91680168897873
# from csv file  165    4.10271
# Name: y_RD, dtype: float64
# from json file  4.102714929875906
# from csv file  263    6.35124
# Name: y_RD, dtype: float64
# from json file  6.35123807154522
# from csv file  293    7.04856
# Name: y_RD, dtype: float64
# from json file  7.048560500416304
# from csv file  214    5.15461
# Name: y_RD, dtype: float64
# from json file  5.154608458288304
# from csv file  177    2.11993
# Name: y_RD, dtype: float64
# from json file  2.119926359998345
# from csv file  169    5.36178
# Name: y_RD, dtype: float64
# from json file  5.361779019509341
# from csv file  272    5.47058
# Name: y_RD, dtype: float64
# from json file  5.470576012681173
# from csv file  267    7.15139
# Name: y_RD, dtype: float64
# from json file  7.1513930962332415
# from csv file  300    4.67667
# Name: y_RD, dtype: float64
# from json file  4.676666416256917
# from csv file  297    4.46388
# Name: y_RD, dtype: float64
# from json file  4.463875017491825
# from csv file  227    7.08618
# Name: y_RD, dtype: float64
# from json file  7.08617890719511
# from csv file  219    5.23849
# Name: y_RD, dtype: float64
# from json file  5.238488495730162
# from csv file  181    4.06953
# Name: y_RD, dtype: float64
# from json file  4.069527997112834
# from csv file  173    5.96322
# Name: y_RD, dtype: float64
# from json file  5.963218809024539
# from csv file  276    4.37733
# Name: y_RD, dtype: float64
# from json file  4.377327241240302
# from csv file  269    4.99429
# Name: y_RD, dtype: float64
# from json file  4.994288696859099
# from csv file  303    3.00196
# Name: y_RD, dtype: float64
# from json file  3.001958466558194
# from csv file  230    3.92567
# Name: y_RD, dtype: float64
# from json file  3.9256661223005707
# from csv file  222    4.99034
# Name: y_RD, dtype: float64
# from json file  4.990341411438543
# from csv file  196    4.08806
# Name: y_RD, dtype: float64
# from json file  4.0880601479379095
# from csv file  186    3.99913
# Name: y_RD, dtype: float64
# from json file  3.999129770008968
# from csv file  284    3.86216
# Name: y_RD, dtype: float64
# from json file  3.862155831499637
# from csv file  280    4.22315
# Name: y_RD, dtype: float64
# from json file  4.223149285217327
# from csv file  308    4.09733
# Name: y_RD, dtype: float64
# from json file  4.097329309986006
# from csv file  306    2.9951
# Name: y_RD, dtype: float64
# from json file  2.9950962970885726
# from csv file  242    3.67236
# Name: y_RD, dtype: float64
# from json file  3.6723554437520294
# from csv file  235    4.35074
# Name: y_RD, dtype: float64
# from json file  4.350735951460384
# from csv file  199    4.51247
# Name: y_RD, dtype: float64
# from json file  4.512466784071402
# from csv file  190    4.24124
# Name: y_RD, dtype: float64
# from json file  4.2412416692679455
# from csv file  287    2.71855
# Name: y_RD, dtype: float64
# from json file  2.718550394051139
# from csv file  246    3.8224
# Name: y_RD, dtype: float64
# from json file  3.8224013969878805
# from csv file  238    3.83373
# Name: y_RD, dtype: float64
# from json file  3.8337325070168857
# from csv file  208    2.25868
# Name: y_RD, dtype: float64
# from json file  2.258679251657213
# from csv file  203    3.50981
# Name: y_RD, dtype: float64
# from json file  3.509808252745471
# from csv file  193    2.93647
# Name: y_RD, dtype: float64
# from json file  2.9364719106541757
# from csv file  256    1.70064
# Name: y_RD, dtype: float64
# from json file  1.7006420920141112
# from csv file  250    2.83099
# Name: y_RD, dtype: float64
# from json file  2.830986261089226
# from csv file  261    6.35898
# Name: y_RD, dtype: float64
# from json file  6.358981506016122
# from csv file  166    4.72852
# Name: y_RD, dtype: float64
# from json file  4.728523659570404
# from csv file  264    5.61162
# Name: y_RD, dtype: float64
# from json file  5.611621526983652
# from csv file  294    5.74674
# Name: y_RD, dtype: float64
# from json file  5.746742730958896
# from csv file  215    4.91076
# Name: y_RD, dtype: float64
# from json file  4.91076164622215
# from csv file  170    5.11836
# Name: y_RD, dtype: float64
# from json file  5.118357529526622
# from csv file  273    6.74981
# Name: y_RD, dtype: float64
# from json file  6.749807251568447
# from csv file  268    5.73252
# Name: y_RD, dtype: float64
# from json file  5.732519493480745
# from csv file  301    5.10663
# Name: y_RD, dtype: float64
# from json file  5.10663244687068
# from csv file  298    5.19428
# Name: y_RD, dtype: float64
# from json file  5.19427523369204
# from csv file  220    5.2641
# Name: y_RD, dtype: float64
# from json file  5.264096011873982
# from csv file  182    3.64783
# Name: y_RD, dtype: float64
# from json file  3.6478269632931264
# from csv file  174    3.20276
# Name: y_RD, dtype: float64
# from json file  3.202762010447712
# from csv file  277    4.84878
# Name: y_RD, dtype: float64
# from json file  4.848782215186282
# from csv file  270    7.25751
# Name: y_RD, dtype: float64
# from json file  7.257508512522947
# from csv file  304    6.83657
# Name: y_RD, dtype: float64
# from json file  6.836566807184581
# from csv file  231    3.04306
# Name: y_RD, dtype: float64
# from json file  3.043062292027232
# from csv file  223    5.38489
# Name: y_RD, dtype: float64
# from json file  5.384894968059709
# from csv file  187    3.32338
# Name: y_RD, dtype: float64
# from json file  3.3233752279939472
# from csv file  285    3.47458
# Name: y_RD, dtype: float64
# from json file  3.47458177260516
# from csv file  281    5.34992
# Name: y_RD, dtype: float64
# from json file  5.3499196489797
# from csv file  243    2.68868
# Name: y_RD, dtype: float64
# from json file  2.688680019730608
# from csv file  236    4.56369
# Name: y_RD, dtype: float64
# from json file  4.563692476306964
# from csv file  200    4.21894
# Name: y_RD, dtype: float64
# from json file  4.218943392164243
# from csv file  191    3.25086
# Name: y_RD, dtype: float64
# from json file  3.250862174353396
# from csv file  247    4.37809
# Name: y_RD, dtype: float64
# from json file  4.37808586556443
# from csv file  239    8.53714
# Name: y_RD, dtype: float64
# from json file  8.537136599903102
# from csv file  265    9.87612
# Name: y_RD, dtype: float64
# from json file  9.876115474525605
# from csv file  295    7.38792
# Name: y_RD, dtype: float64
# from json file  7.3879171276896285
# from csv file  216    3.64243
# Name: y_RD, dtype: float64
# from json file  3.642433725573779
# from csv file  274    3.04096
# Name: y_RD, dtype: float64
# from json file  3.0409561492993076
# from csv file  299    6.13773
# Name: y_RD, dtype: float64
# from json file  6.137725676892676
# from csv file  278    2.86217
# Name: y_RD, dtype: float64
# from json file  2.8621724428304143
# from csv file  232    2.57025
# Name: y_RD, dtype: float64
# from json file  2.570248768099454
# from csv file  224    5.96394
# Name: y_RD, dtype: float64
# from json file  5.9639408352740215
# from csv file  310    2.70395
# Name: y_RD, dtype: float64
# from json file  2.7039486263469863
# from csv file  315    1.99452
# Name: y_RD, dtype: float64
# from json file  1.9945154833258918
# from csv file  338    3.47565
# Name: y_RD, dtype: float64
# from json file  3.475650014903045
# from csv file  342    2.65497
# Name: y_RD, dtype: float64
# from json file  2.6549687059598166
# from csv file  353    3.73649
# Name: y_RD, dtype: float64
# from json file  3.7364877278240383
# from csv file  346    1.50718
# Name: y_RD, dtype: float64
# from json file  1.5071802035469837
# from csv file  356    1.53803
# Name: y_RD, dtype: float64
# from json file  1.5380269257111934
# from csv file  350    0.850512
# Name: y_RD, dtype: float64
# from json file  0.8505119066376134
# from csv file  309    2.56084
# Name: y_RD, dtype: float64
# from json file  2.5608432927529226
# from csv file  311    4.48902
# Name: y_RD, dtype: float64
# from json file  4.489024555646146
# from csv file  324    4.1438
# Name: y_RD, dtype: float64
# from json file  4.143797379684971
# from csv file  316    6.16346
# Name: y_RD, dtype: float64
# from json file  6.1634628727949
# from csv file  359    4.55912
# Name: y_RD, dtype: float64
# from json file  4.559117404231657
# from csv file  326    5.62777
# Name: y_RD, dtype: float64
# from json file  5.627765167225868
# from csv file  320    6.93673
# Name: y_RD, dtype: float64
# from json file  6.936733306070104
# from csv file  369    3.84957
# Name: y_RD, dtype: float64
# from json file  3.8495651974383525
# from csv file  363    4.68908
# Name: y_RD, dtype: float64
# from json file  4.689080515275814
# from csv file  339    2.97409
# Name: y_RD, dtype: float64
# from json file  2.974088571832826
# from csv file  330    6.02374
# Name: y_RD, dtype: float64
# from json file  6.023740651353047
# from csv file  372    3.65999
# Name: y_RD, dtype: float64
# from json file  3.659988993350015
# from csv file  343    4.62595
# Name: y_RD, dtype: float64
# from json file  4.625952483466984
# from csv file  334    2.30875
# Name: y_RD, dtype: float64
# from json file  2.3087549952585467
# from csv file  381    3.04457
# Name: y_RD, dtype: float64
# from json file  3.0445658638793667
# from csv file  376    4.60382
# Name: y_RD, dtype: float64
# from json file  4.603820718828621
# from csv file  354    4.27321
# Name: y_RD, dtype: float64
# from json file  4.273206776012414
# from csv file  347    2.24508
# Name: y_RD, dtype: float64
# from json file  2.2450779621635464
# from csv file  384    1.23157
# Name: y_RD, dtype: float64
# from json file  1.2315686190707262
# from csv file  379    2.83131
# Name: y_RD, dtype: float64
# from json file  2.831309406695287
# from csv file  357    3.45296
# Name: y_RD, dtype: float64
# from json file  3.452960715102506
# from csv file  351    2.40511
# Name: y_RD, dtype: float64
# from json file  2.405110861448161
# from csv file  312    5.61012
# Name: y_RD, dtype: float64
# from json file  5.61012260807164
# from csv file  386    5.2024
# Name: y_RD, dtype: float64
# from json file  5.202395602164109
# from csv file  358    6.55478
# Name: y_RD, dtype: float64
# from json file  6.554775116383122
# from csv file  412    3.28715
# Name: y_RD, dtype: float64
# from json file  3.2871461254055125
# from csv file  409    3.55039
# Name: y_RD, dtype: float64
# from json file  3.5503877108722315
# from csv file  325    4.05367
# Name: y_RD, dtype: float64
# from json file  4.053674229263276
# from csv file  317    5.95972
# Name: y_RD, dtype: float64
# from json file  5.959722693523428
# from csv file  389    5.55787
# Name: y_RD, dtype: float64
# from json file  5.557865992247214
# from csv file  360    4.77416
# Name: y_RD, dtype: float64
# from json file  4.774158286629004
# from csv file  415    3.363
# Name: y_RD, dtype: float64
# from json file  3.362998939494045
# from csv file  327    5.26992
# Name: y_RD, dtype: float64
# from json file  5.269916661971899
# from csv file  321    5.32723
# Name: y_RD, dtype: float64
# from json file  5.327232808609771
# from csv file  396    2.5475
# Name: y_RD, dtype: float64
# from json file  2.547500155402519
# from csv file  392    4.27126
# Name: y_RD, dtype: float64
# from json file  4.271259555208829
# from csv file  370    3.28169
# Name: y_RD, dtype: float64
# from json file  3.2816895677796163
# from csv file  364    3.59418
# Name: y_RD, dtype: float64
# from json file  3.5941767305199743
# from csv file  420    4.98203
# Name: y_RD, dtype: float64
# from json file  4.982031351023206
# from csv file  418    2.47591
# Name: y_RD, dtype: float64
# from json file  2.4759077448175373
# from csv file  340    2.90328
# Name: y_RD, dtype: float64
# from json file  2.903284233292267
# from csv file  331    5.59481
# Name: y_RD, dtype: float64
# from json file  5.594813823313578
# from csv file  399    3.7022
# Name: y_RD, dtype: float64
# from json file  3.70220241529584
# from csv file  373    4.6432
# Name: y_RD, dtype: float64
# from json file  4.643200301386377
# from csv file  367    5.10283
# Name: y_RD, dtype: float64
# from json file  5.102827550036418
# from csv file  344    3.21451
# Name: y_RD, dtype: float64
# from json file  3.214508403302482
# from csv file  335    3.65751
# Name: y_RD, dtype: float64
# from json file  3.6575128851176286
# from csv file  403    1.62789
# Name: y_RD, dtype: float64
# from json file  1.6278944804245306
# from csv file  402    2.93319
# Name: y_RD, dtype: float64
# from json file  2.933189911412706
# from csv file  382    2.75833
# Name: y_RD, dtype: float64
# from json file  2.7583295761963345
# from csv file  377    2.38203
# Name: y_RD, dtype: float64
# from json file  2.382033098843457
# from csv file  355    3.29737
# Name: y_RD, dtype: float64
# from json file  3.2973721130952978
# from csv file  348    2.92111
# Name: y_RD, dtype: float64
# from json file  2.921109691384757
# from csv file  337    1.0571
# Name: y_RD, dtype: float64
# from json file  1.057099782574568
# from csv file  385    2.34652
# Name: y_RD, dtype: float64
# from json file  2.3465235996745806
# from csv file  380    3.78222
# Name: y_RD, dtype: float64
# from json file  3.7822184822852463
# from csv file  352    1.88803
# Name: y_RD, dtype: float64
# from json file  1.8880288270721146
# from csv file  404    4.55302
# Name: y_RD, dtype: float64
# from json file  4.553015079410419
# from csv file  406    5.8014
# Name: y_RD, dtype: float64
# from json file  5.8013997012258995
# from csv file  313    5.14726
# Name: y_RD, dtype: float64
# from json file  5.147257801726469
# from csv file  387    9.49884
# Name: y_RD, dtype: float64
# from json file  9.498840406381742
# from csv file  413    4.75565
# Name: y_RD, dtype: float64
# from json file  4.755648764245163
# from csv file  410    6.20757
# Name: y_RD, dtype: float64
# from json file  6.207572547874293
# from csv file  318    5.13256
# Name: y_RD, dtype: float64
# from json file  5.132562346355256
# from csv file  390    4.17092
# Name: y_RD, dtype: float64
# from json file  4.170919553878012
# from csv file  361    7.00852
# Name: y_RD, dtype: float64
# from json file  7.008523279242915
# from csv file  416    6.11507
# Name: y_RD, dtype: float64
# from json file  6.115071803202228
# from csv file  328    3.21118
# Name: y_RD, dtype: float64
# from json file  3.2111765087288204
# from csv file  322    3.83268
# Name: y_RD, dtype: float64
# from json file  3.8326841025977574
# from csv file  397    3.12909
# Name: y_RD, dtype: float64
# from json file  3.129091751944856
# from csv file  393    4.60881
# Name: y_RD, dtype: float64
# from json file  4.6088098657341465
# from csv file  371    5.45095
# Name: y_RD, dtype: float64
# from json file  5.450953585668791
# from csv file  365    4.1669
# Name: y_RD, dtype: float64
# from json file  4.166904168924369
# from csv file  421    7.01965
# Name: y_RD, dtype: float64
# from json file  7.0196463233455155
# from csv file  419    5.50647
# Name: y_RD, dtype: float64
# from json file  5.506470871027502
# from csv file  341    1.84592
# Name: y_RD, dtype: float64
# from json file  1.8459187455854988
# from csv file  332    4.51597
# Name: y_RD, dtype: float64
# from json file  4.515971392339678
# from csv file  400    2.71069
# Name: y_RD, dtype: float64
# from json file  2.7106934760187964
# from csv file  395    6.96128
# Name: y_RD, dtype: float64
# from json file  6.96127681420484
# from csv file  374    2.96997
# Name: y_RD, dtype: float64
# from json file  2.96996747610502
# from csv file  368    6.06451
# Name: y_RD, dtype: float64
# from json file  6.064510562286111
# from csv file  345    3.91132
# Name: y_RD, dtype: float64
# from json file  3.911324151539952
# from csv file  336    2.83263
# Name: y_RD, dtype: float64
# from json file  2.8326323561390554
# from csv file  383    3.68298
# Name: y_RD, dtype: float64
# from json file  3.6829824239626463
# from csv file  378    4.31788
# Name: y_RD, dtype: float64
# from json file  4.31787810847684
# from csv file  349    2.04789
# Name: y_RD, dtype: float64
# from json file  2.0478894464155215
# from csv file  405    5.1668
# Name: y_RD, dtype: float64
# from json file  5.166800633864642
# from csv file  407    7.50985
# Name: y_RD, dtype: float64
# from json file  7.5098524263359465
# from csv file  314    9.00423
# Name: y_RD, dtype: float64
# from json file  9.00423278681437
# from csv file  388    4.86254
# Name: y_RD, dtype: float64
# from json file  4.862544335515549
# from csv file  414    6.46433
# Name: y_RD, dtype: float64
# from json file  6.464330958188065
# from csv file  411    7.52526
# Name: y_RD, dtype: float64
# from json file  7.525263494406663
# from csv file  319    8.98591
# Name: y_RD, dtype: float64
# from json file  8.985905347173805
# from csv file  391    5.35884
# Name: y_RD, dtype: float64
# from json file  5.358843053720342
# from csv file  362    4.0652
# Name: y_RD, dtype: float64
# from json file  4.065202916881456
# from csv file  417    6.22381
# Name: y_RD, dtype: float64
# from json file  6.223805897750248
# from csv file  329    2.48315
# Name: y_RD, dtype: float64
# from json file  2.483150245462124
# from csv file  323    3.15018
# Name: y_RD, dtype: float64
# from json file  3.150181771513451
# from csv file  398    3.00401
# Name: y_RD, dtype: float64
# from json file  3.0040133754849374
# from csv file  394    5.5083
# Name: y_RD, dtype: float64
# from json file  5.50830382171023
# from csv file  366    6.5042
# Name: y_RD, dtype: float64
# from json file  6.504200323696928
# from csv file  333    3.96453
# Name: y_RD, dtype: float64
# from json file  3.9645310860246044
# from csv file  401    2.40854
# Name: y_RD, dtype: float64
# from json file  2.4085433494792015
# from csv file  375    2.56781
# Name: y_RD, dtype: float64
# from json file  2.5678143277374574
# from csv file  408    3.64793
# Name: y_RD, dtype: float64
# from json file  3.6479291348102074

# %%
import matplotlib.pyplot as plt
import numpy as np
x = (5.27,5.73,6,6.35,6.35,6.35)
y = (0.995,0.997,0.9985,0.997,0.998,1.001)
plt.plot(x,y,"bo")
z = np.polyfit(x,y,2)
print(z)
chi2 = np.sum((np.polyval(z,x)-y)**2)
print(chi2)
# Out:
# [-0.00267419  0.03455901  0.88707985]
# 8.878489793819456e-06

# %%
df_lattice_xduv = pd.read_csv("CSV_Lattice_xduv.txt",sep = " ",header = None)
df_lattice_xduv.columns = ["x","xduv","nan"]
#df_lattice_xduv.describe()
df_lattice_xduv.head()
# Out:
#           x      xduv  nan
# 0  0.015458  0.001977  NaN
# 1  0.026351  0.002816  NaN
# 2  0.033260  0.002863  NaN
# 3  0.040042  0.002725  NaN
# 4  0.053413  0.002169  NaN

# %%
df_lattice_xddv = pd.read_csv("CSV_Lattice_xddv.txt",sep = " ",header = None)
df_lattice_xddv.columns = ["x","xddv","nan"]
#df_lattice_xddv.describe()
df_lattice_xddv.head()
# Out:
#           x      xddv  nan
# 0  0.004327 -0.000628  NaN
# 1  0.011019 -0.001278  NaN
# 2  0.023059 -0.001463  NaN
# 3  0.040447 -0.001181  NaN
# 4  0.057916 -0.000666  NaN

# %%
x_xddv = df_lattice_xddv['x']
xddv_xddv = df_lattice_xddv['xddv']
plt.plot(x_xddv,xddv_xddv,color = 'b',alpha = 0.5,label = r'Lattice $x\delta u_v$')
x_xduv = df_lattice_xduv['x']
xduv_xduv = df_lattice_xduv['xduv']
plt.plot(x_xduv,xduv_xduv,color = 'm',alpha = 0.5,label = r'Lattice $x\delta d_v$')
plt.xlabel('x')
plt.ylabel(r'$xq_{CSV}$')

x_axis = np.arange(0.01,0.9,0.01)
def delta_udv(parameter):
    x = np.arange(0.01,0.9,0.01)
    return x*parameter*(1-x)**4*x**-0.5*(x-0.0909)
y_delta_uv = delta_udv(-0.305)
plt.plot(x_axis,y_delta_uv,'--',color = 'm',label=r' $x\delta u_v$')
y_delta_dv = delta_udv(0.155)
plt.plot(x_axis,y_delta_dv,'--',color = 'b',label=r' $x\delta d_v$')
plt.legend()

# %%
plt.plot(x_axis,y_delta_dv-y_delta_uv,'--',color = 'b',label=r'Lattice $x\delta d_v-\delta u_v$')
plt.xlim(0.25,0.7)
MRST_delta_uv = delta_udv(-0.2)
MRST_delta_dv = delta_udv(0.2)
plt.plot(x_axis,MRST_delta_dv-MRST_delta_uv,label = r'MRST')
plt.xlabel('x')
plt.ylabel(r'$xq_{CSV}$')
plt.legend()
